# %% [markdown]
# ### ARN_G

# %%
from main import main
# Out:
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
main('config/arn_g_bank.json')
# Out:
# Device: cuda
# 36548 normal records, 4640 anormal records
# We use 2321 anomalous records
# -----------------------------------------------------------------------------------------
# There are 26383 records in training set
# Training set is composed by 26383 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 3131 records in validation set
# Validation set is composed by 2551 normal records and 580 abnormal records
# -----------------------------------------------------------------------------------------
# There are 9354 records in test set
# Test set is composed by 7614 normal records and 1740 abnormal records
# Iteration: 0
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0280 | g_loss: 0.1346 (7.34, 0.06, 0.68) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 1.0778 |
# [INFO] Training phase... Elapsed time: 2554 seconds
# AUC: 0.59
# AUPRC: 0.63
# Iteration: 1
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0299 | g_loss: 0.1406 (7.82, 0.06, 0.67) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.7664 |
# [INFO] Training phase... Elapsed time: 4398 seconds
# AUC: 0.86
# AUPRC: 0.71
# Iteration: 2
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0310 | g_loss: 0.1386 (7.11, 0.06, 0.68) | D(x): 0.99 | D(G(x)): 0.00 |  d_loss_val: 2.4721 |
# [INFO] Training phase... Elapsed time: 4385 seconds
# AUC: 0.95
# AUPRC: 0.84
# Iteration: 3
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0287 | g_loss: 0.1355 (7.38, 0.06, 0.67) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.8285 |
# [INFO] Training phase... Elapsed time: 4249 seconds
# AUC: 0.70
# AUPRC: 0.35
# Iteration: 4
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0280 | g_loss: 0.1368 (7.47, 0.06, 0.70) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.7389 |
# [INFO] Training phase... Elapsed time: 3419 seconds
# AUC: 0.79
# AUPRC: 0.66
# Iteration: 5
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0279 | g_loss: 0.1354 (7.43, 0.06, 0.66) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.7517 |
# [INFO] Training phase... Elapsed time: 3422 seconds
# AUC: 0.54
# AUPRC: 0.27
# Iteration: 6
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0277 | g_loss: 0.1402 (7.47, 0.06, 0.68) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.1158 |
# [INFO] Training phase... Elapsed time: 3419 seconds
# AUC: 0.78
# AUPRC: 0.44
# Iteration: 7
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0319 | g_loss: 0.1427 (8.06, 0.06, 0.69) | D(x): 1.00 | D(G(x)): 0.01 |  d_loss_val: 2.5650 |
# [INFO] Training phase... Elapsed time: 2463 seconds
# AUC: 0.93
# AUPRC: 0.88
# Iteration: 8
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0289 | g_loss: 0.1399 (7.82, 0.06, 0.70) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.4072 |
# [INFO] Training phase... Elapsed time: 2186 seconds
# AUC: 0.92
# AUPRC: 0.85
# Iteration: 9
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0272 | g_loss: 0.1359 (7.46, 0.06, 0.67) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.2716 |
# [INFO] Training phase... Elapsed time: 1790 seconds
# AUC: 0.58
# AUPRC: 0.52
# Iteration: 10
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0284 | g_loss: 0.1370 (7.51, 0.06, 0.70) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.3377 |
# [INFO] Training phase... Elapsed time: 1803 seconds
# AUC: 0.96
# AUPRC: 0.88
# Iteration: 11
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0274 | g_loss: 0.1377 (7.57, 0.06, 0.67) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.6523 |
# [INFO] Training phase... Elapsed time: 1799 seconds
# AUC: 0.72
# AUPRC: 0.58
# Iteration: 12
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0290 | g_loss: 0.1392 (7.21, 0.06, 0.69) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.4598 |
# [INFO] Training phase... Elapsed time: 1811 seconds
# AUC: 0.93
# AUPRC: 0.86
# Iteration: 13
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0284 | g_loss: 0.1387 (7.50, 0.06, 0.66) | D(x): 1.00 | D(G(x)): 0.00 |  d_loss_val: 2.4522 |
# [INFO] Training phase... Elapsed time: 1797 seconds
# AUC: 0.83
# AUPRC: 0.67
# Iteration: 14
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0347 | g_loss: 0.1530 (8.69, 0.06, 0.70) | D(x): 1.00 | D(G(x)): 0.01 |  d_loss_val: 2.7958 |
# [INFO] Training phase... Elapsed time: 1804 seconds
# AUC: 0.70
# AUPRC: 0.70
# Iteration: 15
# [INFO] Starting training phase...
# Epoch [348/450] | d_loss: 0.0752 | g_loss: 0.1227 (5.76, 0.06, 0.61) | D(x): 0.99 | D(G(x)): 0.01 |  d_loss_val: 2.0529 |
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ----

# %%
import json
import os
import sys
import numpy as np
import torch

from utils.util import load_arn_models, get_data, get_Loader, get_auc, get_auprc, show_and_save_metrics, predict

def my_import(name):
    components = name.split('.')
    mod = __import__(components[0])
    for comp in components[1:]:
        mod = getattr(mod, comp)
    return mod


def run_test(params):
    DATASET_NAME = params['DATASET_NAME']
    MODEL_NAME = params['MODEL_NAME']

    n_runs = params['n_runs']

    if 'start_runs'  in params:
        start_runs = params['start_runs']
    else:
        start_runs = 0

    seed = params['seed']

    auc_list = []
    auprc_list = []

    for i in range(start_runs, n_runs):
        print(f'Iteration: {i}')
        params['seed'] = seed*(i+1)
        dataset = get_data(params)

        train_loader, val_loader, test_loader = get_Loader(dataset, params)

        idx = params['MODEL_PATH'].rfind('.')
        mod = __import__(params['MODEL_PATH'][:idx], fromlist=params['MODEL_PATH'][idx+1:])
        Model = getattr(mod, params['MODEL_PATH'][idx+1:])

        model = Model(params)

        name_G = f'{MODEL_NAME}_Generator_{DATASET_NAME}_{i}.ckpt'
        name_D = f'{MODEL_NAME}_Discriminator_{DATASET_NAME}_{i}.ckpt'

        path_G = os.path.join(params['SPACE_MODELS'], name_G)
        path_D = os.path.join(params['SPACE_MODELS'], name_D)

        ### Evaluation ###
        load_arn_models(model.G, model.D, path_G, path_D)
        y_true, y_pred = predict(model.D, params['device'], test_loader)

        y_true = 1-y_true
        y_pred = 1-y_pred

        auc_score = get_auc(y_true, y_pred)
        auprc_score = get_auprc(y_true, y_pred)

        auc_list.append(auc_score)
        auprc_list.append(auprc_score)
    show_and_save_metrics(auc_list, auprc_list, params)

def test(fname):
    with open(fname) as fp:
        params = json.load(fp)

    np.random.seed(params['seed'])
    torch.manual_seed(params['seed'])
    torch.cuda.manual_seed(params['seed'])
    torch.use_deterministic_algorithms = True
    torch.backends.cudnn.benchmark = False

    if 'CUDA_VISIBLE_DEVICES' not in os.environ:
        os.environ['CUDA_VISIBLE_DEVICES'] = params['n_gpu']

    device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')
    print(f'Device: {device}')

    DATASET_AREA = params['DATASET_AREA']

    FILE = params['FILE_NAME']
    params['PATH'] = os.path.join(DATASET_AREA, FILE)

    if 'FILE_NAME_2' in params:
        FILE_2 = params['FILE_NAME_2']
        params['PATH_2'] = os.path.join(DATASET_AREA, FILE_2)

    SPACE_MODELS = params['SPACE_MODELS']
    SPACE_AUC = params['SPACE_AUC']
    SPACE_AUPRC = params['SPACE_AUPRC']

    for dir in [SPACE_MODELS, SPACE_AUC, SPACE_AUPRC]:
        if not os.path.exists(dir):
            os.mkdir(dir)

    params['device'] = device
    params['seed'] = 42

    dataset = get_data(params)

    params['show'] = False
    params['nc'] = dataset['x_train'].shape[1]

    params['discreteCol'] = dataset['discreteCol']
    params['selected_columns'] = dataset['selectedColumns']
    params['index'] = dataset['index']

    run_test(params)

# %%
test('config/arn_g_bank.json')
# Out:
# Device: cuda
# 36548 normal records, 4640 anormal records
# We use 2321 anomalous records
# -----------------------------------------------------------------------------------------
# There are 26383 records in training set
# Training set is composed by 26383 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 3131 records in validation set
# Validation set is composed by 2551 normal records and 580 abnormal records
# -----------------------------------------------------------------------------------------
# There are 9354 records in test set
# Test set is composed by 7614 normal records and 1740 abnormal records
# Iteration: 0
# AUC: 0.59
# AUPRC: 0.63
# Iteration: 1
# AUC: 0.86
# AUPRC: 0.71
# Iteration: 2
# AUC: 0.95
# AUPRC: 0.84
# Iteration: 3
# AUC: 0.70
# AUPRC: 0.35
# Iteration: 4
# AUC: 0.79
# AUPRC: 0.66
# Iteration: 5
# AUC: 0.54
# AUPRC: 0.27
# Iteration: 6
# AUC: 0.78
# AUPRC: 0.44
# Iteration: 7
# AUC: 0.93
# AUPRC: 0.88
# Iteration: 8
# AUC: 0.92
# AUPRC: 0.85
# Iteration: 9
# AUC: 0.58
# AUPRC: 0.52
# Iteration: 10
# AUC: 0.96
# AUPRC: 0.88
# Iteration: 11
# AUC: 0.72
# AUPRC: 0.58
# Iteration: 12
# AUC: 0.93
# AUPRC: 0.86
# Iteration: 13
# AUC: 0.83
# AUPRC: 0.67
# Iteration: 14
# AUC: 0.70
# AUPRC: 0.70
# Iteration: 15
# AUC: 0.61
# AUPRC: 0.49
# Iteration: 16
# AUC: 0.84
# AUPRC: 0.71
# Iteration: 17
# AUC: 0.92
# AUPRC: 0.80
# Iteration: 18
# AUC: 0.79
# AUPRC: 0.60
# Iteration: 19
# AUC: 0.56
# AUPRC: 0.22
# AUC:
# [0.5850894374850926, 0.8577400900941702, 0.947678203188923, 0.6950309321304675, 0.7859710560401438, 0.5391940587363266, 0.7764233082434353, 0.9268969140331331, 0.9188504841353948, 0.5817615538828956, 0.9618769417497712, 0.7162424632180888, 0.9265880456147025, 0.8349013009912171, 0.7014764846365891, 0.6118369745387354, 0.8375475907961438, 0.9248293751075605, 0.7949931916101314, 0.5647888115963032]
# **************
# AUPRC:
# [0.6261651200154155, 0.7132668709768389, 0.8438087246358836, 0.3544376710808924, 0.663685759155275, 0.266717820200174, 0.43829854586090394, 0.8829092833503701, 0.8470591730582477, 0.5164392003200493, 0.8826359297982158, 0.5846578632672196, 0.8551206960193416, 0.6702821757873536, 0.7018551564215747, 0.4924747653764288, 0.712054113041219, 0.8045176530428314, 0.595858182522984, 0.2235001860962195]
# **************
# AUC
# 0.77 +/- 0.06
# 95% confidence level, average auc would be between 0.71 and 0.84
# **************
# AUPRC
# 0.63 +/- 0.09
# 95% confidence level, average auc would be between 0.55 and 0.72
