# %%
from main import main

# %%
main('config/arn_n_noT_bank_weak1.json')
# Out:
# Device: cuda
# 36548 normal records, 4640 anormal records
# We use 2321 anomalous records
# -----------------------------------------------------------------------------------------
# There are 26406 records in training set
# Training set is composed by 26383 normal records and 23 abnormal records
# -----------------------------------------------------------------------------------------
# There are 3131 records in validation set
# Validation set is composed by 2551 normal records and 580 abnormal records
# -----------------------------------------------------------------------------------------
# There are 9354 records in test set
# Test set is composed by 7614 normal records and 1740 abnormal records
# Iteration: 0
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0256 | g_loss: 0.6688 (6.17, 0.11, 0.50) | D(x): 0.99 | D(G(x)): 0.01 | d_loss_val: 2.2570 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 373 seconds
# AUC: 0.55
# AUPRC: 0.28
# Iteration: 1
# ...

# %% [markdown]
# ----
