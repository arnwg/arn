# %%
from main import main

# %%
main('config/arn_g_kld_doh_inv.json')
# Out:
# Device: cuda
# 249836 normal records, 19807 anormal records
# We use 9903 anomalous records
# -----------------------------------------------------------------------------------------
# There are 184444 records in training set
# Training set is composed by 184444 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 18073 records in validation set
# Validation set is composed by 15598 normal records and 2475 abnormal records
# -----------------------------------------------------------------------------------------
# There are 57221 records in test set
# Test set is composed by 49794 normal records and 7427 abnormal records
# Iteration: 0
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3521 (31.74, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3387
# [INFO] Training phase... Elapsed time: 11498 seconds
# AUC: 0.94
# AUPRC: 0.56
# Iteration: 1
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3251 (29.31, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.4044
# [INFO] Training phase... Elapsed time: 11593 seconds
# AUC: 0.99
# AUPRC: 0.89
# Iteration: 2
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0006 | g_loss: 0.3624 (32.74, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.0084
# [INFO] Training phase... Elapsed time: 11614 seconds
# AUC: 0.99
# AUPRC: 0.88
# Iteration: 3
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3556 (33.17, 0.03) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.5177
# [INFO] Training phase... Elapsed time: 11641 seconds
# AUC: 0.99
# AUPRC: 0.86
# Iteration: 4
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0001 | g_loss: 0.3564 (31.81, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3355
# [INFO] Training phase... Elapsed time: 11550 seconds
# AUC: 0.99
# AUPRC: 0.83
# Iteration: 5
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3835 (34.87, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.4972
# [INFO] Training phase... Elapsed time: 11605 seconds
# AUC: 0.99
# AUPRC: 0.85
# Iteration: 6
# [INFO] Starting training phase...
# Epoch [ 17/1500] | d_loss: 1.1101 | g_loss: 0.0214 (0.94, 0.01) | D(x): 0.60 | D(G(x)): 0.40 | d_loss_val: 0.5341
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3147 (28.01, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 9.41079
# [INFO] Training phase... Elapsed time: 11460 seconds
# AUC: 0.99
# AUPRC: 0.87
# Iteration: 7
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0001 | g_loss: 0.3459 (30.97, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 7.1125
# [INFO] Training phase... Elapsed time: 11600 seconds
# AUC: 0.99
# AUPRC: 0.87
# Iteration: 8
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3834 (34.66, 0.03) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.6190
# [INFO] Training phase... Elapsed time: 10651 seconds
# AUC: 0.99
# AUPRC: 0.86
# Iteration: 9
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3368 (30.88, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.7433
# [INFO] Training phase... Elapsed time: 11450 seconds
# AUC: 0.98
# AUPRC: 0.75
# Iteration: 10
# [INFO] Starting training phase...
# Epoch [494/1500] | d_loss: 0.0001 | g_loss: 0.2482 (21.11, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.4817

# %%
main('config/arn_g_kld_doh_inv.json')
# Out:
# Device: cuda
# 249836 normal records, 19807 anormal records
# We use 9903 anomalous records
# -----------------------------------------------------------------------------------------
# There are 184444 records in training set
# Training set is composed by 184444 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 18073 records in validation set
# Validation set is composed by 15598 normal records and 2475 abnormal records
# -----------------------------------------------------------------------------------------
# There are 57221 records in test set
# Test set is composed by 49794 normal records and 7427 abnormal records
# Iteration: 10
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3573 (31.59, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.4821
# [INFO] Training phase... Elapsed time: 11014 seconds
# AUC: 0.99
# AUPRC: 0.82
# Iteration: 11
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3607 (32.89, 0.03) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.5779
# [INFO] Training phase... Elapsed time: 9591 seconds
# AUC: 0.99
# AUPRC: 0.87
# Iteration: 12
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3704 (33.28, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.7136
# [INFO] Training phase... Elapsed time: 9389 seconds
# AUC: 0.99
# AUPRC: 0.84
# Iteration: 13
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.4009 (36.46, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.6081
# [INFO] Training phase... Elapsed time: 9246 seconds
# AUC: 0.99
# AUPRC: 0.83
# Iteration: 14
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0002 | g_loss: 0.3291 (29.75, 0.03) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.2503
# [INFO] Training phase... Elapsed time: 9077 seconds
# AUC: 0.99
# AUPRC: 0.93
# Iteration: 15
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3710 (33.44, 0.03) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.5179
# [INFO] Training phase... Elapsed time: 9385 seconds
# AUC: 0.99
# AUPRC: 0.88
# Iteration: 16
# [INFO] Starting training phase...
# Epoch [1500/1500] | d_loss: 0.0000 | g_loss: 0.3096 (27.93, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 9.89299
# [INFO] Training phase... Elapsed time: 9127 seconds
# AUC: 0.98
# AUPRC: 0.83
# Iteration: 17
# [INFO] Starting training phase...
# Epoch [538/1500] | d_loss: 0.0001 | g_loss: 0.2832 (24.46, 0.04) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.9922
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ----

# %%
import json
import os
import sys
import numpy as np
import torch

from utils.util import load_arn_models, get_data, get_Loader, get_auc, get_auprc, show_and_save_metrics, predict

def my_import(name):
    components = name.split('.')
    mod = __import__(components[0])
    for comp in components[1:]:
        mod = getattr(mod, comp)
    return mod


def run_test(params):
    DATASET_NAME = params['DATASET_NAME']
    MODEL_NAME = params['MODEL_NAME']

    n_runs = params['n_runs']

    if 'start_runs'  in params:
        start_runs = params['start_runs']
    else:
        start_runs = 0

    seed = params['seed']

    auc_list = []
    auprc_list = []

    for i in range(start_runs, n_runs):
        print(f'Iteration: {i}')
        params['seed'] = seed*(i+1)
        dataset = get_data(params)

        train_loader, val_loader, test_loader = get_Loader(dataset, params)

        idx = params['MODEL_PATH'].rfind('.')
        mod = __import__(params['MODEL_PATH'][:idx], fromlist=params['MODEL_PATH'][idx+1:])
        Model = getattr(mod, params['MODEL_PATH'][idx+1:])

        model = Model(params)

        name_G = f'{MODEL_NAME}_Generator_{DATASET_NAME}_{i}.ckpt'
        name_D = f'{MODEL_NAME}_Discriminator_{DATASET_NAME}_{i}.ckpt'

        path_G = os.path.join(params['SPACE_MODELS'], name_G)
        path_D = os.path.join(params['SPACE_MODELS'], name_D)

        ### Evaluation ###
        load_arn_models(model.G, model.D, path_G, path_D)
        y_true, y_pred = predict(model.D, params['device'], test_loader)

        y_true = 1-y_true
        y_pred = 1-y_pred

        auc_score = get_auc(y_true, y_pred)
        auprc_score = get_auprc(y_true, y_pred)

        auc_list.append(auc_score)
        auprc_list.append(auprc_score)
    show_and_save_metrics(auc_list, auprc_list, params)

def test(fname):
    with open(fname) as fp:
        params = json.load(fp)

    np.random.seed(params['seed'])
    torch.manual_seed(params['seed'])
    torch.cuda.manual_seed(params['seed'])
    torch.use_deterministic_algorithms = True
    torch.backends.cudnn.benchmark = False

    if 'CUDA_VISIBLE_DEVICES' not in os.environ:
        os.environ['CUDA_VISIBLE_DEVICES'] = params['n_gpu']

    device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')
    print(f'Device: {device}')

    DATASET_AREA = params['DATASET_AREA']

    FILE = params['FILE_NAME']
    params['PATH'] = os.path.join(DATASET_AREA, FILE)

    if 'FILE_NAME_2' in params:
        FILE_2 = params['FILE_NAME_2']
        params['PATH_2'] = os.path.join(DATASET_AREA, FILE_2)

    SPACE_MODELS = params['SPACE_MODELS']
    SPACE_AUC = params['SPACE_AUC']
    SPACE_AUPRC = params['SPACE_AUPRC']

    for dir in [SPACE_MODELS, SPACE_AUC, SPACE_AUPRC]:
        if not os.path.exists(dir):
            os.mkdir(dir)

    params['device'] = device
    params['seed'] = 42

    dataset = get_data(params)

    params['show'] = False
    params['nc'] = dataset['x_train'].shape[1]

    params['discreteCol'] = dataset['discreteCol']
    params['selected_columns'] = dataset['selectedColumns']
    params['index'] = dataset['index']

    run_test(params)

# %%
test('config/arn_g_kld_doh_inv.json')
# Out:
# Device: cuda
# 249836 normal records, 19807 anormal records
# We use 9903 anomalous records
# -----------------------------------------------------------------------------------------
# There are 184444 records in training set
# Training set is composed by 184444 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 18073 records in validation set
# Validation set is composed by 15598 normal records and 2475 abnormal records
# -----------------------------------------------------------------------------------------
# There are 57221 records in test set
# Test set is composed by 49794 normal records and 7427 abnormal records
# Iteration: 0
# AUC: 0.94
# AUPRC: 0.56
# Iteration: 1
# AUC: 0.99
# AUPRC: 0.89
# Iteration: 2
# AUC: 0.99
# AUPRC: 0.88
# Iteration: 3
