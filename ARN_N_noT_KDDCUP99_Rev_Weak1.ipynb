# %%
from main import main

# %%
main('config/arn_n_noT_kddcup99_rev_weak1.json')
# Out:
# Device: cuda
# 97278 normal records, 8752 anormal records
# We use 4376 anomalous records
# -----------------------------------------------------------------------------------------
# There are 81366 records in training set
# Training set is composed by 81323 normal records and 43 abnormal records
# -----------------------------------------------------------------------------------------
# There are 5083 records in validation set
# Validation set is composed by 3989 normal records and 1094 abnormal records
# -----------------------------------------------------------------------------------------
# There are 15248 records in test set
# Test set is composed by 11966 normal records and 3282 abnormal records
# Iteration: 0
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0017 | g_loss: 0.6178 (9.88, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.7879 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1320 seconds
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 1
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0017 | g_loss: 0.6125 (9.44, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.5052 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1386 seconds
# AUC: 0.99
# AUPRC: 0.96
# Iteration: 2
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0009 | g_loss: 0.6353 (11.32, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.2751 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1405 seconds
# AUC: 0.98
# AUPRC: 0.97
# Iteration: 3
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0013 | g_loss: 0.6119 (9.59, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.6753 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1407 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 4
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0020 | g_loss: 0.6185 (9.36, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.1783 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1408 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 5
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0043 | g_loss: 0.6005 (7.80, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.1540 | D(x_ab): 0.003
# [INFO] Training phase... Elapsed time: 1408 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 6
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0033 | g_loss: 0.6168 (10.76, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.1947 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1413 seconds
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 7
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0019 | g_loss: 0.6111 (8.72, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.9228 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1417 seconds
# AUC: 0.99
# AUPRC: 0.99
# Iteration: 8
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0032 | g_loss: 0.6237 (10.37, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.2568 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1411 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 9
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0019 | g_loss: 0.6185 (8.89, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3553 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1422 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 10
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0267 | g_loss: 0.6202 (7.71, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.2560 | D(x_ab): 0.020
# [INFO] Training phase... Elapsed time: 1413 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 11
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0008 | g_loss: 0.6350 (11.57, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3793 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1403 seconds
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 12
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0018 | g_loss: 0.6177 (9.75, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.7423 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1371 seconds
# AUC: 0.99
# AUPRC: 0.90
# Iteration: 13
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0019 | g_loss: 0.6120 (9.53, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3378 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1412 seconds
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 14
# [INFO] Starting training phase...
# Epoch [379/400] | d_loss: 0.0010 | g_loss: 0.6149 (9.90, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.6949 | D(x_ab): 0.002
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ----

# %%
import json
import os
import sys
import numpy as np
import torch

from utils.util import load_arn_models, get_data, get_Loader, get_auc, get_auprc, show_and_save_metrics, predict

def my_import(name):
    components = name.split('.')
    mod = __import__(components[0])
    for comp in components[1:]:
        mod = getattr(mod, comp)
    return mod


def run_test(params):
    DATASET_NAME = params['DATASET_NAME']
    MODEL_NAME = params['MODEL_NAME']

    n_runs = params['n_runs']

    if 'start_runs'  in params:
        start_runs = params['start_runs']
    else:
        start_runs = 0

    seed = params['seed']

    auc_list = []
    auprc_list = []

    for i in range(start_runs, n_runs):
        print(f'Iteration: {i}')
        params['seed'] = seed*(i+1)
        dataset = get_data(params)

        train_loader, val_loader, test_loader = get_Loader(dataset, params)

        idx = params['MODEL_PATH'].rfind('.')
        mod = __import__(params['MODEL_PATH'][:idx], fromlist=params['MODEL_PATH'][idx+1:])
        Model = getattr(mod, params['MODEL_PATH'][idx+1:])

        model = Model(params)

        name_G = f'{MODEL_NAME}_Generator_{DATASET_NAME}_{i}.ckpt'
        name_D = f'{MODEL_NAME}_Discriminator_{DATASET_NAME}_{i}.ckpt'

        path_G = os.path.join(params['SPACE_MODELS'], name_G)
        path_D = os.path.join(params['SPACE_MODELS'], name_D)

        ### Evaluation ###
        load_arn_models(model.G, model.D, path_G, path_D)
        y_true, y_pred = predict(model.D, params['device'], test_loader)

        y_true = 1-y_true
        y_pred = 1-y_pred

        auc_score = get_auc(y_true, y_pred)
        auprc_score = get_auprc(y_true, y_pred)

        auc_list.append(auc_score)
        auprc_list.append(auprc_score)
    show_and_save_metrics(auc_list, auprc_list, params)

def test(fname):
    with open(fname) as fp:
        params = json.load(fp)

    np.random.seed(params['seed'])
    torch.manual_seed(params['seed'])
    torch.cuda.manual_seed(params['seed'])
    torch.use_deterministic_algorithms = True
    torch.backends.cudnn.benchmark = False

    if 'CUDA_VISIBLE_DEVICES' not in os.environ:
        os.environ['CUDA_VISIBLE_DEVICES'] = params['n_gpu']

    device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')
    print(f'Device: {device}')

    DATASET_AREA = params['DATASET_AREA']

    FILE = params['FILE_NAME']
    params['PATH'] = os.path.join(DATASET_AREA, FILE)

    if 'FILE_NAME_2' in params:
        FILE_2 = params['FILE_NAME_2']
        params['PATH_2'] = os.path.join(DATASET_AREA, FILE_2)

    SPACE_MODELS = params['SPACE_MODELS']
    SPACE_AUC = params['SPACE_AUC']
    SPACE_AUPRC = params['SPACE_AUPRC']

    for dir in [SPACE_MODELS, SPACE_AUC, SPACE_AUPRC]:
        if not os.path.exists(dir):
            os.mkdir(dir)

    params['device'] = device
    params['seed'] = 42

    dataset = get_data(params)

    params['show'] = False
    params['nc'] = dataset['x_train'].shape[1]

    params['discreteCol'] = dataset['discreteCol']
    params['selected_columns'] = dataset['selectedColumns']
    params['index'] = dataset['index']

    run_test(params)

# %%
test('config/arn_n_noT_kddcup99_rev_weak1.json')
# Out:
# Device: cuda
# 97278 normal records, 8752 anormal records
# We use 4376 anomalous records
# -----------------------------------------------------------------------------------------
# There are 81366 records in training set
# Training set is composed by 81323 normal records and 43 abnormal records
# -----------------------------------------------------------------------------------------
# There are 5083 records in validation set
# Validation set is composed by 3989 normal records and 1094 abnormal records
# -----------------------------------------------------------------------------------------
# There are 15248 records in test set
# Test set is composed by 11966 normal records and 3282 abnormal records
# Iteration: 0
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 1
# AUC: 0.99
# AUPRC: 0.96
# Iteration: 2
# AUC: 0.98
# AUPRC: 0.97
# Iteration: 3
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 4
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 5
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 6
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 7
# AUC: 0.99
# AUPRC: 0.99
# Iteration: 8
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 9
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 10
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 11
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 12
# AUC: 0.99
# AUPRC: 0.90
# Iteration: 13
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 14
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 15
# AUC: 0.97
# AUPRC: 0.86
# Iteration: 16
# AUC: 0.98
# AUPRC: 0.93
# Iteration: 17
# AUC: 0.99
# AUPRC: 0.99
# Iteration: 18
# AUC: 1.00
# AUPRC: 0.98
# Iteration: 19
# AUC: 1.00
# AUPRC: 0.99
# AUC:
# [0.9919697572942554, 0.9922900712082567, 0.9812363956662503, 0.9984627121960321, 0.9975132416109305, 0.9980383175853829, 0.9938387410480416, 0.988624992017297, 0.9965658462739697, 0.9971268253144218, 0.9959515600926168, 0.9932832493201589, 0.9867520742041512, 0.9947534416780919, 0.995549038342743, 0.9714721621885613, 0.9847517132382905, 0.989097601135372, 0.9951667343477656, 0.9975747860864772]
# **************
# AUPRC:
# [0.9688295879385244, 0.957789565528925, 0.9727599800084185, 0.9949767746273288, 0.9919324410012189, 0.9936786870122449, 0.9738076757024573, 0.9876791312064017, 0.9891378808238251, 0.9899251324806555, 0.9858538173736564, 0.9752988823141394, 0.9024103762962999, 0.9816732794690357, 0.9859128079279947, 0.8563908259434652, 0.9315511897887633, 0.987712143412942, 0.9823908156158154, 0.9917141574234059]
# **************
# AUC
# 0.99 +/- 0.00
# 95% confidence level, average auc would be between 0.99 and 0.99
# **************
# AUPRC
# 0.97 +/- 0.02
# 95% confidence level, average auc would be between 0.96 and 0.99
