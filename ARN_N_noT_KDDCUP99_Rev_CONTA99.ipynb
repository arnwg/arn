# %%
from main import main

# %%
main('config/arn_n_noT_kddcup99_rev_conta99.json')
# Out:
# Device: cuda
# 97278 normal records, 8752 anormal records
# We use 4376 anomalous records
# -----------------------------------------------------------------------------------------
# There are 82136 records in training set
# Training set is composed by 82136 normal records and 0 abnormal records
# There are 813 records anomalies labeled as normal
# -----------------------------------------------------------------------------------------
# There are 5083 records in validation set
# Validation set is composed by 3989 normal records and 1094 abnormal records
# -----------------------------------------------------------------------------------------
# There are 15248 records in test set
# Test set is composed by 11966 normal records and 3282 abnormal records
# Iteration: 0
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0014 | g_loss: 0.6614 (13.87, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.8635
# [INFO] Training phase... Elapsed time: 903 seconds
# ...
