# %%
from main import main

# %%
main('config/arn_n_noT_kddcup99_rev_weak3.json')
# Out:
# Device: cuda
# 97278 normal records, 8752 anormal records
# We use 4376 anomalous records
# -----------------------------------------------------------------------------------------
# There are 81454 records in training set
# Training set is composed by 81323 normal records and 131 abnormal records
# -----------------------------------------------------------------------------------------
# There are 5083 records in validation set
# Validation set is composed by 3989 normal records and 1094 abnormal records
# -----------------------------------------------------------------------------------------
# There are 15248 records in test set
# Test set is composed by 11966 normal records and 3282 abnormal records
# Iteration: 0
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0014 | g_loss: 0.6250 (10.30, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.9751 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1318 seconds
# AUC: 0.99
# AUPRC: 0.93
# Iteration: 1
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0019 | g_loss: 0.6155 (10.10, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.0656 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1381 seconds
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 2
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0011 | g_loss: 0.6316 (10.25, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3189 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1407 seconds
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 3
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0012 | g_loss: 0.6152 (9.93, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.1637 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1407 seconds
# AUC: 0.99
# AUPRC: 0.96
# Iteration: 4
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0015 | g_loss: 0.6121 (8.59, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3089 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1409 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 5
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0041 | g_loss: 0.6089 (8.46, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.4860 | D(x_ab): 0.001
# [INFO] Training phase... Elapsed time: 1405 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 6
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0016 | g_loss: 0.6154 (8.93, 0.03, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.4376 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1408 seconds
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 7
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0014 | g_loss: 0.6143 (10.41, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.1562 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1415 seconds
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 8
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0016 | g_loss: 0.6197 (10.62, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3434 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1405 seconds
# AUC: 0.99
# AUPRC: 0.99
# Iteration: 9
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0018 | g_loss: 0.6378 (10.57, 0.03, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3981 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1417 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 10
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0036 | g_loss: 0.5994 (7.45, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3206 | D(x_ab): 0.00
# [INFO] Training phase... Elapsed time: 1412 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 11
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0020 | g_loss: 0.6097 (8.58, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.6026 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1401 seconds
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 12
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0014 | g_loss: 0.6108 (8.73, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.9776 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1370 seconds
# AUC: 0.99
# AUPRC: 0.91
# Iteration: 13
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0020 | g_loss: 0.6185 (9.28, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.7431 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1407 seconds
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 14
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0010 | g_loss: 0.6153 (9.32, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.3930 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1410 seconds
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 15
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0022 | g_loss: 0.6149 (8.94, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.8949 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1417 seconds
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 16
# [INFO] Starting training phase...
# Epoch [400/400] | d_loss: 0.0057 | g_loss: 0.5954 (7.20, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.01 | d_loss_val: 1.5827 | D(x_ab): 0.000
# [INFO] Training phase... Elapsed time: 1418 seconds
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 17
# [INFO] Starting training phase...
# Epoch [377/400] | d_loss: 0.0062 | g_loss: 0.6289 (10.48, 0.02, 0.50) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 0.2847 | D(x_ab): 0.01
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ----

# %%
import json
import os
import sys
import numpy as np
import torch

from utils.util import load_arn_models, get_data, get_Loader, get_auc, get_auprc, show_and_save_metrics, predict

def my_import(name):
    components = name.split('.')
    mod = __import__(components[0])
    for comp in components[1:]:
        mod = getattr(mod, comp)
    return mod


def run_test(params):
    DATASET_NAME = params['DATASET_NAME']
    MODEL_NAME = params['MODEL_NAME']

    n_runs = params['n_runs']

    if 'start_runs'  in params:
        start_runs = params['start_runs']
    else:
        start_runs = 0

    seed = params['seed']

    auc_list = []
    auprc_list = []

    for i in range(start_runs, n_runs):
        print(f'Iteration: {i}')
        params['seed'] = seed*(i+1)
        dataset = get_data(params)

        train_loader, val_loader, test_loader = get_Loader(dataset, params)

        idx = params['MODEL_PATH'].rfind('.')
        mod = __import__(params['MODEL_PATH'][:idx], fromlist=params['MODEL_PATH'][idx+1:])
        Model = getattr(mod, params['MODEL_PATH'][idx+1:])

        model = Model(params)

        name_G = f'{MODEL_NAME}_Generator_{DATASET_NAME}_{i}.ckpt'
        name_D = f'{MODEL_NAME}_Discriminator_{DATASET_NAME}_{i}.ckpt'

        path_G = os.path.join(params['SPACE_MODELS'], name_G)
        path_D = os.path.join(params['SPACE_MODELS'], name_D)

        ### Evaluation ###
        load_arn_models(model.G, model.D, path_G, path_D)
        y_true, y_pred = predict(model.D, params['device'], test_loader)

        y_true = 1-y_true
        y_pred = 1-y_pred

        auc_score = get_auc(y_true, y_pred)
        auprc_score = get_auprc(y_true, y_pred)

        auc_list.append(auc_score)
        auprc_list.append(auprc_score)
    show_and_save_metrics(auc_list, auprc_list, params)

def test(fname):
    with open(fname) as fp:
        params = json.load(fp)

    np.random.seed(params['seed'])
    torch.manual_seed(params['seed'])
    torch.cuda.manual_seed(params['seed'])
    torch.use_deterministic_algorithms = True
    torch.backends.cudnn.benchmark = False

    if 'CUDA_VISIBLE_DEVICES' not in os.environ:
        os.environ['CUDA_VISIBLE_DEVICES'] = params['n_gpu']

    device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')
    print(f'Device: {device}')

    DATASET_AREA = params['DATASET_AREA']

    FILE = params['FILE_NAME']
    params['PATH'] = os.path.join(DATASET_AREA, FILE)

    if 'FILE_NAME_2' in params:
        FILE_2 = params['FILE_NAME_2']
        params['PATH_2'] = os.path.join(DATASET_AREA, FILE_2)

    SPACE_MODELS = params['SPACE_MODELS']
    SPACE_AUC = params['SPACE_AUC']
    SPACE_AUPRC = params['SPACE_AUPRC']

    for dir in [SPACE_MODELS, SPACE_AUC, SPACE_AUPRC]:
        if not os.path.exists(dir):
            os.mkdir(dir)

    params['device'] = device
    params['seed'] = 42

    dataset = get_data(params)

    params['show'] = False
    params['nc'] = dataset['x_train'].shape[1]

    params['discreteCol'] = dataset['discreteCol']
    params['selected_columns'] = dataset['selectedColumns']
    params['index'] = dataset['index']

    run_test(params)

# %%
test('config/arn_n_noT_kddcup99_rev_weak3.json')
# Out:
# Device: cuda
# 97278 normal records, 8752 anormal records
# We use 4376 anomalous records
# -----------------------------------------------------------------------------------------
# There are 81454 records in training set
# Training set is composed by 81323 normal records and 131 abnormal records
# -----------------------------------------------------------------------------------------
# There are 5083 records in validation set
# Validation set is composed by 3989 normal records and 1094 abnormal records
# -----------------------------------------------------------------------------------------
# There are 15248 records in test set
# Test set is composed by 11966 normal records and 3282 abnormal records
# Iteration: 0
# AUC: 0.99
# AUPRC: 0.93
# Iteration: 1
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 2
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 3
# AUC: 0.99
# AUPRC: 0.96
# Iteration: 4
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 5
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 6
# AUC: 0.99
# AUPRC: 0.97
# Iteration: 7
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 8
# AUC: 0.99
# AUPRC: 0.99
# Iteration: 9
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 10
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 11
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 12
# AUC: 0.99
# AUPRC: 0.91
# Iteration: 13
# AUC: 0.99
# AUPRC: 0.98
# Iteration: 14
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 15
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 16
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 17
# AUC: 0.99
# AUPRC: 0.99
# Iteration: 18
# AUC: 1.00
# AUPRC: 0.99
# Iteration: 19
# AUC: 0.99
# AUPRC: 0.98
# AUC:
# [0.9873745213306482, 0.9948620166237816, 0.9921300479328848, 0.9930955603134333, 0.9970399831820872, 0.9982834260345405, 0.994011470443934, 0.9890612015376087, 0.9908637518877119, 0.9958119455458961, 0.9974320904965044, 0.9893298379534213, 0.9863652504969647, 0.994234706032316, 0.9961730514540333, 0.9903835292825915, 0.9870975329959362, 0.9927746225518311, 0.9983151022147557, 0.992185010179665]
# **************
# AUPRC:
# [0.926407400144552, 0.9785902919628171, 0.971184747479728, 0.9639379841957242, 0.9902874120034041, 0.994375600882024, 0.9666660172488115, 0.9477523284660229, 0.9871268215613717, 0.99120953387393, 0.9914285362968907, 0.9549694388557526, 0.9128098100297259, 0.9763835157850191, 0.9875793887930691, 0.9478421572529264, 0.946284837998455, 0.9903964456933807, 0.9936372524387748, 0.9759785282839479]
# **************
# AUC
# 0.99 +/- 0.00
# 95% confidence level, average auc would be between 0.99 and 0.99
# **************
# AUPRC
# 0.97 +/- 0.01
# 95% confidence level, average auc would be between 0.96 and 0.98
