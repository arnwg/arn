# %%
from main import main
# Out:
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/liguori/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
main('config/arn_n_kld_bank.json')
# Out:
# Device: cuda
# 36548 normal records, 4640 anormal records
# We use 2321 anomalous records
# -----------------------------------------------------------------------------------------
# There are 26383 records in training set
# Training set is composed by 26383 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 3131 records in validation set
# Validation set is composed by 2551 normal records and 580 abnormal records
# -----------------------------------------------------------------------------------------
# There are 9354 records in test set
# Test set is composed by 7614 normal records and 1740 abnormal records
# Iteration: 0
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0277 | g_loss: 0.0828 (7.38, 0.01) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.6529
# [INFO] Training phase... Elapsed time: 320 seconds
# AUC: 0.67
# AUPRC: 0.33
# Iteration: 1
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0272 | g_loss: 0.0887 (7.23, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.7757
# [INFO] Training phase... Elapsed time: 318 seconds
# AUC: 0.50
# AUPRC: 0.19
# Iteration: 2
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0283 | g_loss: 0.0928 (7.55, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.1456
# [INFO] Training phase... Elapsed time: 332 seconds
# AUC: 0.60
# AUPRC: 0.31
# Iteration: 3
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0285 | g_loss: 0.0938 (7.04, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.3571
# [INFO] Training phase... Elapsed time: 325 seconds
# AUC: 0.79
# AUPRC: 0.51
# Iteration: 4
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0306 | g_loss: 0.1031 (7.83, 0.03) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.9796
# [INFO] Training phase... Elapsed time: 330 seconds
# AUC: 0.70
# AUPRC: 0.47
# Iteration: 5
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0292 | g_loss: 0.0841 (7.15, 0.01) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.8768
# [INFO] Training phase... Elapsed time: 325 seconds
# AUC: 0.55
# AUPRC: 0.21
# Iteration: 6
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0286 | g_loss: 0.0807 (7.61, 0.00) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.6846
# [INFO] Training phase... Elapsed time: 319 seconds
# AUC: 0.52
# AUPRC: 0.23
# Iteration: 7
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0326 | g_loss: 0.0821 (7.76, 0.00) | D(x): 1.00 | D(G(x)): 0.01 | d_loss_val: 2.2283
# [INFO] Training phase... Elapsed time: 325 seconds
# AUC: 0.68
# AUPRC: 0.45
# Iteration: 8
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0287 | g_loss: 0.0937 (7.17, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.7292
# [INFO] Training phase... Elapsed time: 331 seconds
# AUC: 0.62
# AUPRC: 0.39
# Iteration: 9
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0285 | g_loss: 0.0999 (7.34, 0.03) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.8929
# [INFO] Training phase... Elapsed time: 323 seconds
# AUC: 0.55
# AUPRC: 0.27
# Iteration: 10
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0287 | g_loss: 0.0972 (7.59, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.6917
# [INFO] Training phase... Elapsed time: 319 seconds
# AUC: 0.51
# AUPRC: 0.19
# Iteration: 11
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0305 | g_loss: 0.0800 (7.20, 0.01) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.4625
# [INFO] Training phase... Elapsed time: 324 seconds
# AUC: 0.93
# AUPRC: 0.84
# Iteration: 12
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0283 | g_loss: 0.0895 (7.56, 0.01) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.7744
# [INFO] Training phase... Elapsed time: 325 seconds
# AUC: 0.41
# AUPRC: 0.16
# Iteration: 13
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0283 | g_loss: 0.1022 (7.49, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.9893
# [INFO] Training phase... Elapsed time: 324 seconds
# AUC: 0.82
# AUPRC: 0.70
# Iteration: 14
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0278 | g_loss: 0.0943 (7.50, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.5716
# [INFO] Training phase... Elapsed time: 315 seconds
# AUC: 0.75
# AUPRC: 0.60
# Iteration: 15
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0275 | g_loss: 0.0776 (7.37, 0.00) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.6762
# [INFO] Training phase... Elapsed time: 329 seconds
# AUC: 0.53
# AUPRC: 0.26
# Iteration: 16
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0306 | g_loss: 0.0715 (6.54, 0.01) | D(x): 1.00 | D(G(x)): 0.01 | d_loss_val: 2.2853
# [INFO] Training phase... Elapsed time: 322 seconds
# AUC: 0.50
# AUPRC: 0.23
# Iteration: 17
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0276 | g_loss: 0.0883 (7.38, 0.01) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.7625
# [INFO] Training phase... Elapsed time: 319 seconds
# AUC: 0.56
# AUPRC: 0.28
# Iteration: 18
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0283 | g_loss: 0.0801 (7.42, 0.01) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 2.6745
# [INFO] Training phase... Elapsed time: 324 seconds
# AUC: 0.49
# AUPRC: 0.19
# Iteration: 19
# [INFO] Starting training phase...
# Epoch [450/450] | d_loss: 0.0276 | g_loss: 0.0955 (7.83, 0.02) | D(x): 1.00 | D(G(x)): 0.00 | d_loss_val: 1.3119
# [INFO] Training phase... Elapsed time: 330 seconds
# AUC: 0.97
# AUPRC: 0.95
# AUC:
# [0.6741398935415404, 0.49692565721342113, 0.5960755519928504, 0.7921924675959893, 0.6978847193162022, 0.5453467070641196, 0.5236097901928993, 0.6756056976108742, 0.6219577743962271, 0.5504226938277643, 0.512884915566908, 0.9318246182923774, 0.4126902122224939, 0.820264432729787, 0.7458547699488842, 0.527807441826762, 0.5024883457273202, 0.5644399759668367, 0.4886829388694147, 0.9748483208487692]
# **************
# AUPRC:
# [0.33263927220809797, 0.18948406410809152, 0.3085663529737821, 0.5126450518791046, 0.46511852514487023, 0.2104537210293199, 0.23147880825960626, 0.44976780223033397, 0.3875116108442262, 0.273338657258258, 0.1912296278718769, 0.8409546523486916, 0.16444729555774956, 0.697375820145524, 0.6039694286325183, 0.2556764078920186, 0.2324262841073198, 0.27959204373768487, 0.18715072408265895, 0.9505023932166727]
# **************
# AUC
# 0.63 +/- 0.07
# 95% confidence level, average auc would be between 0.57 and 0.70
# **************
# AUPRC
# 0.39 +/- 0.10
# 95% confidence level, average auc would be between 0.29 and 0.49

# %% [markdown]
# ----

# %% [markdown]
# ### Test

# %%
import json
import os
import sys
import numpy as np
import torch

from utils.util import load_arn_models, get_data, get_Loader, get_auc, get_auprc, show_and_save_metrics, predict

def my_import(name):
    components = name.split('.')
    mod = __import__(components[0])
    for comp in components[1:]:
        mod = getattr(mod, comp)
    return mod


def run_test(params):
    DATASET_NAME = params['DATASET_NAME']
    MODEL_NAME = params['MODEL_NAME']

    n_runs = params['n_runs']

    if 'start_runs'  in params:
        start_runs = params['start_runs']
    else:
        start_runs = 0

    seed = params['seed']

    auc_list = []
    auprc_list = []

    for i in range(start_runs, n_runs):
        print(f'Iteration: {i}')
        params['seed'] = seed*(i+1)
        dataset = get_data(params)

        train_loader, val_loader, test_loader = get_Loader(dataset, params)

        idx = params['MODEL_PATH'].rfind('.')
        mod = __import__(params['MODEL_PATH'][:idx], fromlist=params['MODEL_PATH'][idx+1:])
        Model = getattr(mod, params['MODEL_PATH'][idx+1:])

        model = Model(params)

        name_G = f'{MODEL_NAME}_Generator_{DATASET_NAME}_{i}.ckpt'
        name_D = f'{MODEL_NAME}_Discriminator_{DATASET_NAME}_{i}.ckpt'

        path_G = os.path.join(params['SPACE_MODELS'], name_G)
        path_D = os.path.join(params['SPACE_MODELS'], name_D)

        ### Evaluation ###
        load_arn_models(model.G, model.D, path_G, path_D)
        y_true, y_pred = predict(model.D, params['device'], test_loader)

        y_true = 1-y_true
        y_pred = 1-y_pred

        auc_score = get_auc(y_true, y_pred)
        auprc_score = get_auprc(y_true, y_pred)

        auc_list.append(auc_score)
        auprc_list.append(auprc_score)
    show_and_save_metrics(auc_list, auprc_list, params)

def test(fname):
    with open(fname) as fp:
        params = json.load(fp)

    np.random.seed(params['seed'])
    torch.manual_seed(params['seed'])
    torch.cuda.manual_seed(params['seed'])
    torch.use_deterministic_algorithms = True
    torch.backends.cudnn.benchmark = False

    if 'CUDA_VISIBLE_DEVICES' not in os.environ:
        os.environ['CUDA_VISIBLE_DEVICES'] = params['n_gpu']

    device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')
    print(f'Device: {device}')

    DATASET_AREA = params['DATASET_AREA']

    FILE = params['FILE_NAME']
    params['PATH'] = os.path.join(DATASET_AREA, FILE)

    if 'FILE_NAME_2' in params:
        FILE_2 = params['FILE_NAME_2']
        params['PATH_2'] = os.path.join(DATASET_AREA, FILE_2)

    SPACE_MODELS = params['SPACE_MODELS']
    SPACE_AUC = params['SPACE_AUC']
    SPACE_AUPRC = params['SPACE_AUPRC']

    for dir in [SPACE_MODELS, SPACE_AUC, SPACE_AUPRC]:
        if not os.path.exists(dir):
            os.mkdir(dir)

    params['device'] = device
    params['seed'] = 42

    dataset = get_data(params)

    params['show'] = False
    params['nc'] = dataset['x_train'].shape[1]

    params['discreteCol'] = dataset['discreteCol']
    params['selected_columns'] = dataset['selectedColumns']
    params['index'] = dataset['index']

    run_test(params)

# %%
test('config/arn_g_kld_bank.json')
# Out:
# Device: cuda
# 36548 normal records, 4640 anormal records
# We use 2321 anomalous records
# -----------------------------------------------------------------------------------------
# There are 26383 records in training set
# Training set is composed by 26383 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 3131 records in validation set
# Validation set is composed by 2551 normal records and 580 abnormal records
# -----------------------------------------------------------------------------------------
# There are 9354 records in test set
# Test set is composed by 7614 normal records and 1740 abnormal records
# Iteration: 0
# AUC: 0.54
# AUPRC: 0.20
# Iteration: 1
# AUC: 0.99
# AUPRC: 0.95
# Iteration: 2
# AUC: 0.80
# AUPRC: 0.41
# Iteration: 3
# AUC: 0.56
# AUPRC: 0.32
# Iteration: 4
# AUC: 0.75
# AUPRC: 0.58
# Iteration: 5
# AUC: 0.64
# AUPRC: 0.35
# Iteration: 6
# AUC: 0.95
# AUPRC: 0.71
# Iteration: 7
# AUC: 0.64
# AUPRC: 0.54
# Iteration: 8
# AUC: 0.56
# AUPRC: 0.24
# Iteration: 9
# AUC: 0.80
# AUPRC: 0.76
# Iteration: 10
# AUC: 0.97
# AUPRC: 0.82
# Iteration: 11
# AUC: 0.66
# AUPRC: 0.35
# Iteration: 12
# AUC: 0.48
# AUPRC: 0.17
# Iteration: 13
# AUC: 0.90
# AUPRC: 0.75
# Iteration: 14
# AUC: 0.64
# AUPRC: 0.32
# Iteration: 15
# AUC: 0.66
# AUPRC: 0.30
# Iteration: 16
# AUC: 0.63
# AUPRC: 0.33
# Iteration: 17
# AUC: 0.91
# AUPRC: 0.71
# Iteration: 18
# AUC: 0.93
# AUPRC: 0.83
# Iteration: 19
# AUC: 0.80
# AUPRC: 0.61
# AUC:
# [0.5402349422871963, 0.9888440154102093, 0.7958329936686503, 0.5635643204139984, 0.7512700817308708, 0.6445795555072478, 0.9452933419683645, 0.6430552913719132, 0.5583782445525334, 0.8039390535885196, 0.9711093297585511, 0.6571266934171474, 0.48053928939129065, 0.9040310649770991, 0.6359039911355067, 0.6595924325727864, 0.6346930865405227, 0.9052712184753433, 0.9265969146369815, 0.7993400315208825]
# **************
# AUPRC:
# [0.1990963466211967, 0.9477895787284241, 0.4083491966511831, 0.31953132657974676, 0.5830204586601531, 0.346555902989249, 0.7147753244340656, 0.536466111167524, 0.23575309528722113, 0.7559132767911597, 0.8236334360826971, 0.3530223373740425, 0.16633849462060202, 0.7489563148610188, 0.3203259148636213, 0.29969039920046264, 0.3259565221968111, 0.7142334301454586, 0.8290475174093292, 0.611534760390418]
# **************
# AUC
# 0.74 +/- 0.07
# 95% confidence level, average auc would be between 0.67 and 0.81
# **************
# AUPRC
# 0.51 +/- 0.10
# 95% confidence level, average auc would be between 0.41 and 0.62
