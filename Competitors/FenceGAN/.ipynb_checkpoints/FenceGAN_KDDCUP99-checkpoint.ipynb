# %% [markdown]
# ---

# %% [markdown]
# # KDDCUP99

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '0'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

from load_data import get_KDDCUP99
from FGAN_MODEL import FenceGAN

# %%
def meanAUC_PRAUC(auc_list, pr_list, name, SPACE_AUC, SPACE_AUPRC):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AU_NAME = f'{name}.csv'
    
    AUC_Frame.to_csv(os.path.join(SPACE_AUC, AU_NAME), index=False)
    PR_AUC_Frame.to_csv(os.path.join(SPACE_AUPRC, AU_NAME), index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

WORK_SPACE = '../Dataset'
FILE = 'kddcup.data_10_percent_corrected'

SPACE_MODELS = './models'
SPACE_AUC = './auc'
SPACE_AUPRC = './auprc'

for n in (SPACE_MODELS, SPACE_AUC, SPACE_AUPRC):
    if not os.path.exists(n):
        os.mkdir(n)
        
DATASET = 'KDDCUP99'

PATH = os.path.join(WORK_SPACE, FILE)

# %%
dataset = get_KDDCUP99(PATH, seed, show=True)
# Out:
# 97278 normal records, 396743 anormal records
# We use 198372 anomalous records
# -----------------------------------------------------------------------------------------
# There are 77822 records in training set
# Training set is composed by 77822 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 14783 records in validation set
# Validation set is composed by 4864 normal records and 9919 abnormal records
# -----------------------------------------------------------------------------------------
# There are 44348 records in test set
# Test set is composed by 14592 normal records and 29756 abnormal records

# %%
nc = dataset['x_train'].shape[1]
z_dim = 32
gamma = 0.1
alpha = 0.5 
beta = 30 
_power = 2
v_freq = 4

g_objective_anneal = 1
repeat = 4 
baseline = 0.5

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 200
seed = 42
pr_list = []

for i in range(n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_KDDCUP99(PATH, seed*(i+1), show=False)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    trainer = FenceGAN(nc, z_dim, gamma, alpha, beta, _power, v_freq, g_objective_anneal, repeat, baseline, device)
    
    d_losses, g_losses = trainer.train(train_loader, test_loader, val_loader, batch_size, n_epochs)

    # Save models
    NAME_D = f'D_FGAN_{DATASET}_{i}.ckpt'
    NAME_G = f'G_FGAN_{DATASET}_{i}.ckpt'
    
    torch.save(trainer.D.state_dict(), os.path.join(SPACE_MODELS, NAME_D))
    torch.save(trainer.G.state_dict(), os.path.join(SPACE_MODELS, NAME_G))
    
    _auc, pr_auc = trainer.predict(test_loader)
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 1
# Epoch #1: Loss: 0.8014
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.094 | g_loss: 2.8764
# [INFO] Training phase... Elapsed time: 369 seconds
# PR AUC: 0.99
# AUC: 0.99
# Iteration: 2
# Epoch #1: Loss: 0.7403
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.100 | g_loss: 2.8287
# [INFO] Training phase... Elapsed time: 379 seconds
# PR AUC: 1.00
# AUC: 0.99
# Iteration: 3
# Epoch #1: Loss: 0.7710
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.099 | g_loss: 2.9069
# [INFO] Training phase... Elapsed time: 358 seconds
# PR AUC: 0.99
# AUC: 0.99
# Iteration: 4
# Epoch #1: Loss: 0.7828
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.090 | g_loss: 2.8709
# [INFO] Training phase... Elapsed time: 370 seconds
# PR AUC: 1.00
# AUC: 0.99
# Iteration: 5
# Epoch #1: Loss: 0.8043
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.097 | g_loss: 2.7357
# [INFO] Training phase... Elapsed time: 363 seconds
# PR AUC: 0.97
# AUC: 0.97
# Iteration: 6
# Epoch #1: Loss: 0.7543
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.093 | g_loss: 2.9826
# [INFO] Training phase... Elapsed time: 366 seconds
# PR AUC: 1.00
# AUC: 0.99
# Iteration: 7
# Epoch #1: Loss: 0.7158
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.095 | g_loss: 2.8560
# [INFO] Training phase... Elapsed time: 376 seconds
# PR AUC: 1.00
# AUC: 0.99
# Iteration: 8
# Epoch #1: Loss: 0.7000
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.094 | g_loss: 2.9087
# [INFO] Training phase... Elapsed time: 396 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 9
# Epoch #1: Loss: 0.7632
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.095 | g_loss: 2.8169
# [INFO] Training phase... Elapsed time: 379 seconds
# PR AUC: 1.00
# AUC: 1.00
# Iteration: 10
# Epoch #1: Loss: 0.7809
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.100 | g_loss: 2.8344
# [INFO] Training phase... Elapsed time: 381 seconds
# PR AUC: 0.99
# AUC: 0.98
# Iteration: 11
# Epoch #1: Loss: 0.7644
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.101 | g_loss: 3.0235
# [INFO] Training phase... Elapsed time: 398 seconds
# PR AUC: 1.00
# AUC: 0.99
# Iteration: 12
# Epoch #1: Loss: 0.7288
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.090 | g_loss: 2.8629
# [INFO] Training phase... Elapsed time: 379 seconds
# PR AUC: 0.99
# AUC: 0.99
# Iteration: 13
# Epoch #1: Loss: 0.7572
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.087 | g_loss: 2.9683
# [INFO] Training phase... Elapsed time: 381 seconds
# PR AUC: 1.00
# AUC: 1.00
# Iteration: 14
# Epoch #1: Loss: 0.7300
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.086 | g_loss: 2.5576
# [INFO] Training phase... Elapsed time: 396 seconds
# PR AUC: 0.99
# AUC: 0.99
# Iteration: 15
# Epoch #1: Loss: 0.7601
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.099 | g_loss: 2.5998
# [INFO] Training phase... Elapsed time: 375 seconds
# PR AUC: 1.00
# AUC: 0.99
# Iteration: 16
# Epoch #1: Loss: 0.7299
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.092 | g_loss: 2.7071
# [INFO] Training phase... Elapsed time: 372 seconds
# PR AUC: 1.00
# AUC: 1.00
# Iteration: 17
# Epoch #1: Loss: 0.7150
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.098 | g_loss: 2.8319
# [INFO] Training phase... Elapsed time: 374 seconds
# PR AUC: 0.99
# AUC: 0.99
# Iteration: 18
# Epoch #1: Loss: 0.7545
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.088 | g_loss: 2.7369
# [INFO] Training phase... Elapsed time: 374 seconds
# PR AUC: 0.99
# AUC: 0.98
# Iteration: 19
# Epoch #1: Loss: 0.7346
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.096 | g_loss: 2.6322
# [INFO] Training phase... Elapsed time: 374 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 20
# Epoch #1: Loss: 0.7875
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.090 | g_loss: 2.7957
# [INFO] Training phase... Elapsed time: 443 seconds
# PR AUC: 1.00
# AUC: 0.99

# %%
meanAUC_PRAUC(auc_list, pr_list, 'FGAN_KDDCUP99', SPACE_AUC, SPACE_AUPRC)
# Out:
# AUC:
# [0.9892206141659032, 0.9944339475043954, 0.9911728352036624, 0.9948947022405035, 0.9671365840101096, 0.9949431189187408, 0.9941985879801183, 0.9816188007029543, 0.995398130903645, 0.9842054719577416, 0.9942168295926755, 0.9915977688526034, 0.9955363760946487, 0.991541308637739, 0.992212029044194, 0.9959855923573133, 0.991688205380737, 0.9837592278308017, 0.975122590637772, 0.9933000529673508]
# **************
# PR AUC:
# [0.99159963748441, 0.9971904539277419, 0.9938758101217041, 0.9972712614705765, 0.97137387145073, 0.9971306542194788, 0.9964493816084021, 0.9849302872296956, 0.9979379992850322, 0.9878121558069565, 0.9962152884967106, 0.9939778296386412, 0.997672021223109, 0.9939273006096652, 0.9952151921357562, 0.9982928146565656, 0.9945436010894098, 0.9873051777394832, 0.9796370109532347, 0.9961528934392432]
# **************
# AUC
# 0.99 +/- 0.00
# 95% confidence level, average auc would be between 0.99 and 0.99
# **************
# PR AUC
# 0.99 +/- 0.00
# 95% confidence level, average auc would be between 0.99 and 1.00

# %% [markdown]
# ---
