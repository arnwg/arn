# %% [markdown]
# ---

# %% [markdown]
# # DoH

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '2'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

from load_data import get_DoH
from FGAN_MODEL import FenceGAN

# %%
def meanAUC_PRAUC(auc_list, pr_list, name, SPACE_AUC, SPACE_AUPRC):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AU_NAME = f'{name}.csv'
    
    AUC_Frame.to_csv(os.path.join(SPACE_AUC, AU_NAME), index=False)
    PR_AUC_Frame.to_csv(os.path.join(SPACE_AUPRC, AU_NAME), index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

WORK_SPACE = '../Dataset'
DATASET_AREA = 'CIRA-CIC-DoHBrw-2020'

SPACE_MODELS = './models'
SPACE_AUC = './auc'
SPACE_AUPRC = './auprc'

for n in (SPACE_MODELS, SPACE_AUC, SPACE_AUPRC):
    if not os.path.exists(n):
        os.mkdir(n)
        
FILE_3 = 'l2-benign.csv'
FILE_4 = 'l2-malicious.csv'

DATASET = 'DoH'

PATH_B = os.path.join(WORK_SPACE, DATASET_AREA, FILE_3)
PATH_M = os.path.join(WORK_SPACE, DATASET_AREA, FILE_4)

# %%
dataset = get_DoH(PATH_B, PATH_M, seed, show=True)
# Out:
# 19807 normal records, 249836 anormal records
# We use 124918 anomalous records
# -----------------------------------------------------------------------------------------
# There are 15846 records in training set
# Training set is composed by 15846 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 7236 records in validation set
# Validation set is composed by 990 normal records and 6246 abnormal records
# -----------------------------------------------------------------------------------------
# There are 21709 records in test set
# Test set is composed by 2971 normal records and 18738 abnormal records

# %%
nc = dataset['x_train'].shape[1]
z_dim = 32
gamma = 0.1
alpha = 0.5 
beta = 30 
_power = 2
v_freq = 4

g_objective_anneal = 1
repeat = 4 
baseline = 0.5

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 800
seed = 42
pr_list = []

for i in range(n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_DoH(PATH_B, PATH_M, seed*(i+1), show=False)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    trainer = FenceGAN(nc, z_dim, gamma, alpha, beta, _power, v_freq, g_objective_anneal, repeat, baseline, device)
    
    d_losses, g_losses = trainer.train(train_loader, test_loader, val_loader, batch_size, n_epochs)
    
    # Save models
    NAME_D = f'D_FGAN_{DATASET}_{i}.ckpt'
    NAME_G = f'G_FGAN_{DATASET}_{i}.ckpt'
    
    torch.save(trainer.D.state_dict(), os.path.join(SPACE_MODELS, NAME_D))
    torch.save(trainer.G.state_dict(), os.path.join(SPACE_MODELS, NAME_G))
    
    _auc, pr_auc = trainer.predict(test_loader)
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 1
# Epoch #1: Loss: 0.7702
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.085 | g_loss: 3.2598
# [INFO] Training phase... Elapsed time: 439 seconds
# PR AUC: 0.96
# AUC: 0.84
# Iteration: 2
# Epoch #1: Loss: 0.7621
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.087 | g_loss: 3.1361
# [INFO] Training phase... Elapsed time: 441 seconds
# PR AUC: 0.96
# AUC: 0.84
# Iteration: 3
# Epoch #1: Loss: 0.7706
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.093 | g_loss: 3.2428
# [INFO] Training phase... Elapsed time: 444 seconds
# PR AUC: 0.98
# AUC: 0.90
# Iteration: 4
# Epoch #1: Loss: 0.7616
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.087 | g_loss: 3.0446
# [INFO] Training phase... Elapsed time: 448 seconds
# PR AUC: 0.97
# AUC: 0.85
# Iteration: 5
# Epoch #1: Loss: 0.7526
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.088 | g_loss: 2.9905
# [INFO] Training phase... Elapsed time: 445 seconds
# PR AUC: 0.98
# AUC: 0.93
# Iteration: 6
# Epoch #1: Loss: 0.7369
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.093 | g_loss: 3.0806
# [INFO] Training phase... Elapsed time: 441 seconds
# PR AUC: 0.97
# AUC: 0.87
# Iteration: 7
# Epoch #1: Loss: 0.7658
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.095 | g_loss: 3.0554
# [INFO] Training phase... Elapsed time: 447 seconds
# PR AUC: 0.95
# AUC: 0.82
# Iteration: 8
# Epoch #1: Loss: 0.7301
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.095 | g_loss: 2.9989
# [INFO] Training phase... Elapsed time: 436 seconds
# PR AUC: 0.98
# AUC: 0.91
# Iteration: 9
# Epoch #1: Loss: 0.7318
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.088 | g_loss: 3.1042
# [INFO] Training phase... Elapsed time: 440 seconds
# PR AUC: 0.99
# AUC: 0.96
# Iteration: 10
# Epoch #1: Loss: 0.7801
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.083 | g_loss: 2.9977
# [INFO] Training phase... Elapsed time: 439 seconds
# PR AUC: 0.97
# AUC: 0.91
# Iteration: 11
# Epoch #1: Loss: 0.8125
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.087 | g_loss: 3.1889
# [INFO] Training phase... Elapsed time: 440 seconds
# PR AUC: 0.97
# AUC: 0.90
# Iteration: 12
# Epoch #1: Loss: 0.7650
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.088 | g_loss: 3.0583
# [INFO] Training phase... Elapsed time: 441 seconds
# PR AUC: 0.96
# AUC: 0.83
# Iteration: 13
# Epoch #1: Loss: 0.7819
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.087 | g_loss: 3.1579
# [INFO] Training phase... Elapsed time: 446 seconds
# PR AUC: 0.96
# AUC: 0.85
# Iteration: 14
# Epoch #1: Loss: 0.7312
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.082 | g_loss: 3.1501
# [INFO] Training phase... Elapsed time: 451 seconds
# PR AUC: 0.98
# AUC: 0.92
# Iteration: 15
# Epoch #1: Loss: 0.7843
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.086 | g_loss: 3.3809
# [INFO] Training phase... Elapsed time: 453 seconds
# PR AUC: 0.99
# AUC: 0.94
# Iteration: 16
# Epoch #1: Loss: 0.7549
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.093 | g_loss: 2.9472
# [INFO] Training phase... Elapsed time: 452 seconds
# PR AUC: 0.97
# AUC: 0.90
# Iteration: 17
# Epoch #1: Loss: 0.7817
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.093 | g_loss: 3.1761
# [INFO] Training phase... Elapsed time: 453 seconds
# PR AUC: 0.97
# AUC: 0.91
# Iteration: 18
# Epoch #1: Loss: 0.7998
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.099 | g_loss: 3.1930
# [INFO] Training phase... Elapsed time: 446 seconds
# PR AUC: 0.96
# AUC: 0.82
# Iteration: 19
# Epoch #1: Loss: 0.7651
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.089 | g_loss: 3.0449
# [INFO] Training phase... Elapsed time: 446 seconds
# PR AUC: 0.96
# AUC: 0.84
# Iteration: 20
# Epoch #1: Loss: 0.7840
# [INFO] Starting training phase...
# Epoch [800/800] | d_loss: 0.088 | g_loss: 3.3255
# [INFO] Training phase... Elapsed time: 445 seconds
# PR AUC: 0.97
# AUC: 0.89

# %%
meanAUC_PRAUC(auc_list, pr_list, 'FGAN_LR_DoH', SPACE_AUC, SPACE_AUPRC)
# Out:
# AUC:
# [0.8354028189170879, 0.8443217998125332, 0.9045152703407282, 0.853789786845832, 0.9263109226884899, 0.8705793765678609, 0.8165600358738736, 0.9120625217641816, 0.9593862005937138, 0.9085506230775534, 0.8951469858469995, 0.832038062533476, 0.8512770870541035, 0.9188299629905179, 0.9371675152474561, 0.904012365737476, 0.9081901275786548, 0.8247800302055316, 0.8353511040064632, 0.8945861871287966]
# **************
# PR AUC:
# [0.9557437615617469, 0.959203056225393, 0.9757922833043362, 0.9656501390713176, 0.9785068029446291, 0.9668808050365422, 0.9533482735237839, 0.9762932178189411, 0.9902685978728416, 0.9743620063685673, 0.9737291396057346, 0.9561040549495204, 0.9634028563466576, 0.9799013126799793, 0.985976151045238, 0.9724418311650196, 0.9740341654008388, 0.9566023284552877, 0.95886314117108, 0.9735432408624274]
# **************
# AUC
# 0.88 +/- 0.02
# 95% confidence level, average auc would be between 0.86 and 0.90
# **************
# PR AUC
# 0.97 +/- 0.00
# 95% confidence level, average auc would be between 0.97 and 0.97

# %% [markdown]
# ---
