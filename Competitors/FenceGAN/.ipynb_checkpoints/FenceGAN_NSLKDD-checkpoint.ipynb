# %% [markdown]
# ---

# %% [markdown]
# # NSLKDD

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '3'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

from load_data import get_NSLKDD
from FGAN_MODEL import FenceGAN

# %%
def meanAUC_PRAUC(auc_list, pr_list, name, SPACE_AUC, SPACE_AUPRC):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AU_NAME = f'{name}.csv'
    
    AUC_Frame.to_csv(os.path.join(SPACE_AUC, AU_NAME), index=False)
    PR_AUC_Frame.to_csv(os.path.join(SPACE_AUPRC, AU_NAME), index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

WORK_SPACE = '../Dataset'

SPACE_MODELS = './models'
SPACE_AUC = './auc'
SPACE_AUPRC = './auprc'

for n in (SPACE_MODELS, SPACE_AUC, SPACE_AUPRC):
    if not os.path.exists(n):
        os.mkdir(n)
        

DATASET = 'NSL-KDD'
FILE1 = 'KDDTrain+.txt'
FILE2 = 'KDDTest+.txt'

PATH_TRAIN = os.path.join(WORK_SPACE, DATASET, FILE1)
PATH_TEST = os.path.join(WORK_SPACE, DATASET, FILE2)

# %%
dataset = get_NSLKDD(PATH_TRAIN, PATH_TEST, seed, show=True)
# Out:
# 77054 normal records, 71463 anormal records
# We use 35732 anomalous records
# -----------------------------------------------------------------------------------------
# There are 68501 records in training set
# Training set is composed by 68501 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 4314 records in validation set
# Validation set is composed by 2157 normal records and 2157 abnormal records
# -----------------------------------------------------------------------------------------
# There are 12792 records in test set
# Test set is composed by 6396 normal records and 6396 abnormal records

# %%
nc = dataset['x_train'].shape[1]
z_dim = 32
gamma = 0.1
alpha = 0.5 
beta = 30 
_power = 2
v_freq = 4

g_objective_anneal = 1
repeat = 4 
baseline = 0.5

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 200
seed = 42
pr_list = []

for i in range(n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_NSLKDD(PATH_TRAIN, PATH_TEST, seed*(i+1), show=False)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    trainer = FenceGAN(nc, z_dim, gamma, alpha, beta, _power, v_freq, g_objective_anneal, repeat, baseline, device)
    
    d_losses, g_losses = trainer.train(train_loader, test_loader, val_loader, batch_size, n_epochs)
    
    # Save models
    NAME_D = f'D_FGAN_{DATASET}_{i}.ckpt'
    NAME_G = f'G_FGAN_{DATASET}_{i}.ckpt'
    
    torch.save(trainer.D.state_dict(), os.path.join(SPACE_MODELS, NAME_D))
    torch.save(trainer.G.state_dict(), os.path.join(SPACE_MODELS, NAME_G))
    
    _auc, pr_auc = trainer.predict(test_loader)
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 1
# Epoch #1: Loss: 0.7866
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.086 | g_loss: 2.7332
# [INFO] Training phase... Elapsed time: 459 seconds
# PR AUC: 0.97
# AUC: 0.97
# Iteration: 2
# Epoch #1: Loss: 0.7194
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.089 | g_loss: 2.7210
# [INFO] Training phase... Elapsed time: 458 seconds
# PR AUC: 0.97
# AUC: 0.97
# Iteration: 3
# Epoch #1: Loss: 0.7277
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.085 | g_loss: 2.6837
# [INFO] Training phase... Elapsed time: 459 seconds
# PR AUC: 0.97
# AUC: 0.96
# Iteration: 4
# Epoch #1: Loss: 0.7393
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.086 | g_loss: 2.7025
# [INFO] Training phase... Elapsed time: 465 seconds
# PR AUC: 0.98
# AUC: 0.97
# Iteration: 5
# Epoch #1: Loss: 0.7626
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.094 | g_loss: 2.7732
# [INFO] Training phase... Elapsed time: 458 seconds
# PR AUC: 0.97
# AUC: 0.97
# Iteration: 6
# Epoch #1: Loss: 0.7937
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.086 | g_loss: 2.5292
# [INFO] Training phase... Elapsed time: 463 seconds
# PR AUC: 0.97
# AUC: 0.96
# Iteration: 7
# Epoch #1: Loss: 0.7405
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.084 | g_loss: 2.7719
# [INFO] Training phase... Elapsed time: 458 seconds
# PR AUC: 0.96
# AUC: 0.96
# Iteration: 8
# Epoch #1: Loss: 0.7641
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.094 | g_loss: 2.7308
# [INFO] Training phase... Elapsed time: 455 seconds
# PR AUC: 0.97
# AUC: 0.97
# Iteration: 9
# Epoch #1: Loss: 0.7347
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.087 | g_loss: 2.7836
# [INFO] Training phase... Elapsed time: 455 seconds
# PR AUC: 0.96
# AUC: 0.96
# Iteration: 10
# Epoch #1: Loss: 0.7523
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.093 | g_loss: 2.7505
# [INFO] Training phase... Elapsed time: 455 seconds
# PR AUC: 0.96
# AUC: 0.96
# Iteration: 11
# Epoch #1: Loss: 0.7493
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.089 | g_loss: 2.7238
# [INFO] Training phase... Elapsed time: 455 seconds
# PR AUC: 0.97
# AUC: 0.96
# Iteration: 12
# Epoch #1: Loss: 0.7725
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.089 | g_loss: 2.7317
# [INFO] Training phase... Elapsed time: 464 seconds
# PR AUC: 0.97
# AUC: 0.97
# Iteration: 13
# Epoch #1: Loss: 0.7690
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.090 | g_loss: 2.8628
# [INFO] Training phase... Elapsed time: 471 seconds
# PR AUC: 0.97
# AUC: 0.96
# Iteration: 15
# Epoch #1: Loss: 0.7688
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.096 | g_loss: 2.7704
# [INFO] Training phase... Elapsed time: 471 seconds
# PR AUC: 0.97
# AUC: 0.96
# Iteration: 16
# Epoch #1: Loss: 0.7342
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.092 | g_loss: 2.8014
# [INFO] Training phase... Elapsed time: 471 seconds
# PR AUC: 0.97
# AUC: 0.97
# Iteration: 17
# Epoch #1: Loss: 0.7638
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.085 | g_loss: 2.6757
# [INFO] Training phase... Elapsed time: 467 seconds
# PR AUC: 0.97
# AUC: 0.96
# Iteration: 18
# Epoch #1: Loss: 0.8083
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.094 | g_loss: 2.8238
# [INFO] Training phase... Elapsed time: 445 seconds
# PR AUC: 0.98
# AUC: 0.97
# Iteration: 19
# Epoch #1: Loss: 0.7714
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.091 | g_loss: 2.7224
# [INFO] Training phase... Elapsed time: 443 seconds
# PR AUC: 0.96
# AUC: 0.96
# Iteration: 20
# Epoch #1: Loss: 0.8084
# [INFO] Starting training phase...
# Epoch [200/200] | d_loss: 0.093 | g_loss: 2.6504
# [INFO] Training phase... Elapsed time: 440 seconds
# PR AUC: 0.97
# AUC: 0.96

# %%
meanAUC_PRAUC(auc_list, pr_list, 'FGAN_LR_NSLKDD', SPACE_AUC, SPACE_AUPRC)
# Out:
# AUC:
# [0.9672266853188808, 0.968207060795893, 0.963863620496863, 0.9696028357310561, 0.9654876836327897, 0.963944581040918, 0.9588638791208233, 0.9652907945319169, 0.9621052953475848, 0.9595136412650027, 0.9630654184662788, 0.9661650192955964, 0.9641288445013907, 0.963381670591493, 0.9621214043447261, 0.9670250784085269, 0.9642777488353611, 0.9719196101886693, 0.9570100977745236, 0.9648036379248912]
# **************
# PR AUC:
# [0.9688052261818136, 0.973822242984381, 0.9688296357832692, 0.9758871775506361, 0.9679196515654627, 0.9704116757566041, 0.962448806885091, 0.9704408944291817, 0.9643944317584591, 0.9648530947314343, 0.9672534944823743, 0.970341716281686, 0.9693190194764035, 0.9666760052119967, 0.9651917717193688, 0.9723667732668325, 0.9662570201836849, 0.9759362359726512, 0.9614581773500683, 0.9665928728176212]
# **************
# AUC
# 0.96 +/- 0.00
# 95% confidence level, average auc would be between 0.96 and 0.97
# **************
# PR AUC
# 0.97 +/- 0.00
# 95% confidence level, average auc would be between 0.97 and 0.97

# %% [markdown]
# ---
