# %% [markdown]
# ---

# %% [markdown]
# # CoverType

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '2'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

from load_data import get_CoverType
from FGAN_MODEL import FenceGAN

# %%
def meanAUC_PRAUC(auc_list, pr_list, name, SPACE_AUC, SPACE_AUPRC):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AU_NAME = f'{name}.csv'
    
    AUC_Frame.to_csv(os.path.join(SPACE_AUC, AU_NAME), index=False)
    PR_AUC_Frame.to_csv(os.path.join(SPACE_AUPRC, AU_NAME), index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

WORK_SPACE = '../Dataset'

SPACE_MODELS = './models'
SPACE_AUC = './auc'
SPACE_AUPRC = './auprc'

for n in (SPACE_MODELS, SPACE_AUC, SPACE_AUPRC):
    if not os.path.exists(n):
        os.mkdir(n)
        
FILE = 'covtype.data'

DATASET = 'CoverType'

PATH = os.path.join(WORK_SPACE, DATASET, FILE)

# %%
dataset = get_CoverType(PATH, seed, show=True)
# Out:
# 530895 normal records, 50117 anormal records
# We use 25059 anomalous records
# -----------------------------------------------------------------------------------------
# There are 444764 records in training set
# Training set is composed by 444764 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 27797 records in validation set
# Validation set is composed by 21532 normal records and 6265 abnormal records
# -----------------------------------------------------------------------------------------
# There are 83393 records in test set
# Test set is composed by 64599 normal records and 18794 abnormal records

# %%
nc = dataset['x_train'].shape[1]
z_dim = 32
gamma = 0.1
alpha = 0.5 
beta = 30 
_power = 2
v_freq = 4

g_objective_anneal = 1
repeat = 4 
baseline = 0.5

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 30
seed = 42
pr_list = []

for i in range(n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_CoverType(PATH, seed*(i+1), show=False)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    trainer = FenceGAN(nc, z_dim, gamma, alpha, beta, _power, v_freq, g_objective_anneal, repeat, baseline, device)
    
    d_losses, g_losses = trainer.train(train_loader, test_loader, val_loader, batch_size, n_epochs)
    
    # Save models
    NAME_D = f'D_FGAN_{DATASET}_{i}.ckpt'
    NAME_G = f'G_FGAN_{DATASET}_{i}.ckpt'
    
    torch.save(trainer.D.state_dict(), os.path.join(SPACE_MODELS, NAME_D))
    torch.save(trainer.G.state_dict(), os.path.join(SPACE_MODELS, NAME_G))
    
    _auc, pr_auc = trainer.predict(test_loader)
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 1
# Epoch #1: Loss: 0.7065
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.101 | g_loss: 3.1665
# [INFO] Training phase... Elapsed time: 468 seconds
# PR AUC: 0.39
# AUC: 0.68
# Iteration: 2
# Epoch #1: Loss: 0.6961
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.107 | g_loss: 3.1283
# [INFO] Training phase... Elapsed time: 480 seconds
# PR AUC: 0.44
# AUC: 0.76
# Iteration: 3
# Epoch #1: Loss: 0.7273
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.102 | g_loss: 2.9907
# [INFO] Training phase... Elapsed time: 477 seconds
# PR AUC: 0.37
# AUC: 0.68
# Iteration: 4
# Epoch #1: Loss: 0.6825
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.104 | g_loss: 2.9511
# [INFO] Training phase... Elapsed time: 484 seconds
# PR AUC: 0.45
# AUC: 0.77
# Iteration: 5
# Epoch #1: Loss: 0.7207
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.097 | g_loss: 3.3410
# [INFO] Training phase... Elapsed time: 477 seconds
# PR AUC: 0.40
# AUC: 0.67
# Iteration: 6
# Epoch #1: Loss: 0.6766
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.098 | g_loss: 3.0269
# [INFO] Training phase... Elapsed time: 481 seconds
# PR AUC: 0.44
# AUC: 0.71
# Iteration: 7
# Epoch #1: Loss: 0.6708
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.102 | g_loss: 3.2247
# [INFO] Training phase... Elapsed time: 476 seconds
# PR AUC: 0.42
# AUC: 0.69
# Iteration: 8
# Epoch #1: Loss: 0.7479
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.104 | g_loss: 3.0522
# [INFO] Training phase... Elapsed time: 476 seconds
# PR AUC: 0.41
# AUC: 0.69
# Iteration: 9
# Epoch #1: Loss: 0.7233
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.099 | g_loss: 3.2108
# [INFO] Training phase... Elapsed time: 473 seconds
# PR AUC: 0.41
# AUC: 0.73
# Iteration: 10
# Epoch #1: Loss: 0.7323
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.095 | g_loss: 2.9974
# [INFO] Training phase... Elapsed time: 474 seconds
# PR AUC: 0.35
# AUC: 0.54
# Iteration: 11
# Epoch #1: Loss: 0.7314
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.104 | g_loss: 3.1948
# [INFO] Training phase... Elapsed time: 476 seconds
# PR AUC: 0.38
# AUC: 0.69
# Iteration: 12
# Epoch #1: Loss: 0.7136
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.095 | g_loss: 3.3411
# [INFO] Training phase... Elapsed time: 484 seconds
# PR AUC: 0.46
# AUC: 0.76
# Iteration: 13
# Epoch #1: Loss: 0.6855
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.099 | g_loss: 3.2590
# [INFO] Training phase... Elapsed time: 486 seconds
# PR AUC: 0.39
# AUC: 0.67
# Iteration: 14
# Epoch #1: Loss: 0.7067
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.102 | g_loss: 3.1157
# [INFO] Training phase... Elapsed time: 488 seconds
# PR AUC: 0.49
# AUC: 0.76
# Iteration: 15
# Epoch #1: Loss: 0.6977
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.099 | g_loss: 3.0607
# [INFO] Training phase... Elapsed time: 489 seconds
# PR AUC: 0.44
# AUC: 0.77
# Iteration: 16
# Epoch #1: Loss: 0.6939
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.103 | g_loss: 3.2244
# [INFO] Training phase... Elapsed time: 487 seconds
# PR AUC: 0.37
# AUC: 0.61
# Iteration: 17
# Epoch #1: Loss: 0.7143
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.102 | g_loss: 3.2808
# [INFO] Training phase... Elapsed time: 484 seconds
# PR AUC: 0.46
# AUC: 0.74
# Iteration: 18
# Epoch #1: Loss: 0.7057
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.101 | g_loss: 2.9479
# [INFO] Training phase... Elapsed time: 483 seconds
# PR AUC: 0.42
# AUC: 0.73
# Iteration: 19
# Epoch #1: Loss: 0.7399
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.101 | g_loss: 3.2520
# [INFO] Training phase... Elapsed time: 462 seconds
# PR AUC: 0.35
# AUC: 0.60
# Iteration: 20
# Epoch #1: Loss: 0.7231
# [INFO] Starting training phase...
# Epoch [ 30/30] | d_loss: 0.099 | g_loss: 2.9154
# [INFO] Training phase... Elapsed time: 449 seconds
# PR AUC: 0.43
# AUC: 0.74

# %%
meanAUC_PRAUC(auc_list, pr_list, 'FGAN_LR_CoverType', SPACE_AUC, SPACE_AUPRC)
# Out:
# AUC:
# [0.6804583831797757, 0.7581127873559916, 0.6834044051362071, 0.7674027619870685, 0.6723097479149053, 0.712113433837388, 0.6923657440090991, 0.691954064686256, 0.7341708835403182, 0.5429984596831766, 0.6918296405992372, 0.7635679903743826, 0.666885335863236, 0.7603884224462748, 0.7699268626551461, 0.6088766314058226, 0.7353476663918184, 0.7295752894408941, 0.6044121800964348, 0.7357926126432898]
# **************
# PR AUC:
# [0.3851438038607382, 0.44494933708466433, 0.3716331148610277, 0.4541369217796366, 0.40286699852561936, 0.44460529109205493, 0.4171723317498621, 0.405558297816255, 0.4077726939257688, 0.35021938451348245, 0.37634217841727347, 0.45580946134511313, 0.3887191348849602, 0.48771297307814593, 0.4432731912681031, 0.3696439194313894, 0.46400050782069036, 0.42388984700573024, 0.3504554139365984, 0.4298320599025608]
# **************
# AUC
# 0.70 +/- 0.03
# 95% confidence level, average auc would be between 0.67 and 0.73
# **************
# PR AUC
# 0.41 +/- 0.02
# 95% confidence level, average auc would be between 0.40 and 0.43

# %% [markdown]
# ---
