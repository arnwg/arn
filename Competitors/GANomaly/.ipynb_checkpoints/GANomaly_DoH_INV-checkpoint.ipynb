# %% [markdown]
# ---

# %% [markdown]
# # DoH_INV

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '3'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

from load_data import get_DoH_INV
from model_ganomaly import GANomaly

# %%
def meanAUC_PRAUC(auc_list, pr_list, name):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AUC_Frame.to_csv(f'./auc/{name}.csv', index=False)
    PR_AUC_Frame.to_csv(f'./auc_PR/{name}.csv', index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

WORK_SPACE = '../Dataset'
DATASET_AREA = 'CIRA-CIC-DoHBrw-2020'

FILE_3 = 'l2-benign.csv'
FILE_4 = 'l2-malicious.csv'

DATASET = 'DoH'

PATH_B = os.path.join(WORK_SPACE, DATASET_AREA, FILE_3)
PATH_M = os.path.join(WORK_SPACE, DATASET_AREA, FILE_4)

# %%
dataset = get_DoH_INV(PATH_B, PATH_M, seed, show=True)
# Out:
# 249836 normal records, 19807 anormal records
# We use 9903 anomalous records
# -----------------------------------------------------------------------------------------
# There are 184444 records in training set
# Training set is composed by 184444 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 18073 records in validation set
# Validation set is composed by 15598 normal records and 2475 abnormal records
# -----------------------------------------------------------------------------------------
# There are 57221 records in test set
# Test set is composed by 49794 normal records and 7427 abnormal records

# %%
args = {}
nc = dataset['x_train'].shape[1]
nz = 100
manualseed = -1
print_freq = 100
args['w_adv'] = 1
args['w_con'] = 50
args['w_enc'] = 1
isTrain = True

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 800
seed = 42
pr_list = []

for i in range(n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_DoH_INV(PATH_B, PATH_M, seed*(i+1), show=False)
    
    # Convert Normal Label in 0 and Anomalous in 1
    dataset['y_test'].replace({1:0, 0:1}, inplace = True)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    ganomaly = GANomaly(nc, nz, device)
    
    _auc, pr_auc = ganomaly.train_and_test(train_loader, test_loader, args, n_epochs, batch_size)
    
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 1
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.7049
# [INFO] Training phase... Elapsed time: 5229 seconds
# PR AUC: 0.95
# AUC: 0.99
# Iteration: 2
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.000 | g_loss: 0.6421
# [INFO] Training phase... Elapsed time: 6078 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 3
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.005 | g_loss: 0.6626
# [INFO] Training phase... Elapsed time: 6580 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 4
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6739
# [INFO] Training phase... Elapsed time: 6702 seconds
# PR AUC: 0.97
# AUC: 1.00
# Iteration: 5
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6738
# [INFO] Training phase... Elapsed time: 6446 seconds
# PR AUC: 0.97
# AUC: 0.99
# Iteration: 6
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.009 | g_loss: 0.6468
# [INFO] Training phase... Elapsed time: 6324 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 7
# [INFO] Starting training phase...
#
# Epoch [278/800] | d_loss: 0.002 | g_loss: 0.6794
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Epoch [800/800] | d_loss: 0.000 | g_loss: 0.659
# [INFO] Training phase... Elapsed time: 6457 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 8
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6185
# [INFO] Training phase... Elapsed time: 6337 seconds
# PR AUC: 0.98
# AUC: 1.00
# Iteration: 9
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6915
# [INFO] Training phase... Elapsed time: 6311 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 10
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.7204
# [INFO] Training phase... Elapsed time: 5942 seconds
# PR AUC: 0.98
# AUC: 1.00
# Iteration: 11
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.7433
# [INFO] Training phase... Elapsed time: 5683 seconds
# PR AUC: 0.98
# AUC: 1.00
# Iteration: 12
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.000 | g_loss: 0.6815
# [INFO] Training phase... Elapsed time: 5532 seconds
# PR AUC: 0.98
# AUC: 1.00
# Iteration: 13
# [INFO] Starting training phase...
#
# Epoch [304/800] | d_loss: 0.003 | g_loss: 0.6920*****************************************************************************************
# [INFO] Exiting from training early
#
# [INFO] Training phase... Elapsed time: 2059 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-acaa5bb8872d> in <module>
#      27     ganomaly = GANomaly(nc, nz, device)
#      28
# ---> 29     _auc, pr_auc = ganomaly.train_and_test(train_loader, test_loader, args, n_epochs, batch_size)
#      30
#      31     print(f'AUC: {_auc:.2f}')
#
# ~/GCN_Tab/PR_8/PR/model_ganomaly.py in train_and_test(self, train_loader, test_loader, args, num_epochs, bs)
#     195         print(f'\n[INFO] Training phase... Elapsed time: {(time() - start):.0f} seconds\n')
#     196         self.plotLoss(d_losses, g_losses)
# --> 197         _auc, pr_auc = self.test(test_loader)
#     198
#     199         return _auc, pr_auc
#
# ~/GCN_Tab/PR_8/PR/model_ganomaly.py in test(self, test_loader)
#      69         self.G.eval()
#      70
# ---> 71         for i, (batch, label) in enumerate(test_loader, 0):
#      72             bs = batch.size(0)
#      73
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     344     def __next__(self):
#     345         index = self._next_index()  # may raise StopIteration
# --> 346         data = self.dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self.pin_memory:
#     348             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
# ---> 47         return self.collate_fn(data)
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      77         return elem_type(*(default_collate(samples) for samples in zip(*batch)))
#      78     elif isinstance(elem, container_abcs.Sequence):
# ---> 79         transposed = zip(*batch)
#      80         return [default_collate(samples) for samples in transposed]
#      81
#
# KeyboardInterrupt:

# %%
meanAUC_PRAUC(auc_list, pr_list, 'GANomaly_DoH_INV')
# Out:
# AUC:
# [0.9886204692348227, 0.9988318777902455, 0.9986284301879823, 0.9953024881793993, 0.9929260255497567, 0.9985775757234657, 0.999180541969443, 0.9975145749133258, 0.9981255477562847, 0.9970496866370447, 0.9980946732799807, 0.996375718289229]
# **************
# PR AUC:
# [0.9528845335166982, 0.9913867971971189, 0.9909986919905805, 0.9659567713175937, 0.9712021194889995, 0.9904661139854842, 0.9914157026234053, 0.984976618215064, 0.9875103315065988, 0.9793077285550389, 0.9843473905371529, 0.9766192582680632]
# **************
# AUC
# 1.00 +/- 0.00
# 95% confidence level, average auc would be between 0.99 and 1.00
# **************
# PR AUC
# 0.98 +/- 0.01
# 95% confidence level, average auc would be between 0.97 and 0.99

# %%
for i in range(12, n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_DoH_INV(PATH_B, PATH_M, seed*(i+1), show=False)
    
    # Convert Normal Label in 0 and Anomalous in 1
    dataset['y_test'].replace({1:0, 0:1}, inplace = True)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    ganomaly = GANomaly(nc, nz, device)
    
    _auc, pr_auc = ganomaly.train_and_test(train_loader, test_loader, args, n_epochs, batch_size)
    
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 13
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6608
# [INFO] Training phase... Elapsed time: 5496 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 14
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.000 | g_loss: 0.6241
# [INFO] Training phase... Elapsed time: 5755 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 15
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.034 | g_loss: 0.7258
# [INFO] Training phase... Elapsed time: 6482 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 16
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6049
# [INFO] Training phase... Elapsed time: 5061 seconds
# PR AUC: 0.94
# AUC: 0.98
# Iteration: 17
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6723
# [INFO] Training phase... Elapsed time: 5274 seconds
# PR AUC: 0.99
# AUC: 1.00
# Iteration: 18
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.007 | g_loss: 0.6894
# [INFO] Training phase... Elapsed time: 5384 seconds
# PR AUC: 0.98
# AUC: 1.00
# Iteration: 19
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.000 | g_loss: 0.6663
# [INFO] Training phase... Elapsed time: 5252 seconds
# PR AUC: 0.95
# AUC: 0.99
# Iteration: 20
# [INFO] Starting training phase...
#
# Epoch [800/800] | d_loss: 0.001 | g_loss: 0.6669
# [INFO] Training phase... Elapsed time: 5110 seconds
# PR AUC: 0.99
# AUC: 1.00

# %%
auc_list
# Out:
# [0.9886204692348227,
#  0.9988318777902455,
#  0.9986284301879823,
#  0.9953024881793993,
#  0.9929260255497567,
#  0.9985775757234657,
#  0.999180541969443,
#  0.9975145749133258,
#  0.9981255477562847,
#  0.9970496866370447,
#  0.9980946732799807,
#  0.996375718289229,
#  0.9990529096208681,
#  0.9987968796866544,
#  0.9982032477104446,
#  0.9823152078633445,
#  0.9985918069696373,
#  0.9974666299720623,
#  0.9859119423918288,
#  0.9990400601278399]

# %%
meanAUC_PRAUC(auc_list, pr_list, 'GANomaly_DoH_INV')
# Out:
# AUC:
# [0.9886204692348227, 0.9988318777902455, 0.9986284301879823, 0.9953024881793993, 0.9929260255497567, 0.9985775757234657, 0.999180541969443, 0.9975145749133258, 0.9981255477562847, 0.9970496866370447, 0.9980946732799807, 0.996375718289229, 0.9990529096208681, 0.9987968796866544, 0.9982032477104446, 0.9823152078633445, 0.9985918069696373, 0.9974666299720623, 0.9859119423918288, 0.9990400601278399]
# **************
# PR AUC:
# [0.9528845335166982, 0.9913867971971189, 0.9909986919905805, 0.9659567713175937, 0.9712021194889995, 0.9904661139854842, 0.9914157026234053, 0.984976618215064, 0.9875103315065988, 0.9793077285550389, 0.9843473905371529, 0.9766192582680632, 0.9927279879542623, 0.9903389004156025, 0.9860864145064724, 0.9433685491503903, 0.9883958463628617, 0.984856516780028, 0.9475526337722439, 0.9923373344828659]
# **************
# AUC
# 1.00 +/- 0.00
# 95% confidence level, average auc would be between 0.99 and 1.00
# **************
# PR AUC
# 0.98 +/- 0.01
# 95% confidence level, average auc would be between 0.97 and 0.99

# %% [markdown]
# ---
