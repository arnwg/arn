# %% [markdown]
# ---

# %% [markdown]
# # NSLKDD

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '3'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

from load_data import get_NSLKDD
from model_ganomaly import GANomaly

# %%
def meanAUC_PRAUC(auc_list, pr_list, name):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AUC_Frame.to_csv(f'./auc/{name}.csv', index=False)
    PR_AUC_Frame.to_csv(f'./auc_PR/{name}.csv', index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

WORK_SPACE = '../Dataset'
DATASET = 'NSL-KDD'
FILE1 = 'KDDTrain+.txt'
FILE2 = 'KDDTest+.txt'

PATH_TRAIN = os.path.join(WORK_SPACE, DATASET, FILE1)
PATH_TEST = os.path.join(WORK_SPACE, DATASET, FILE2)

# %%
dataset = get_NSLKDD(PATH_TRAIN, PATH_TEST, seed, show=True)
# Out:
# 77054 normal records, 71463 anormal records
# We use 35732 anomalous records
# -----------------------------------------------------------------------------------------
# There are 68501 records in training set
# Training set is composed by 68501 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 4314 records in validation set
# Validation set is composed by 2157 normal records and 2157 abnormal records
# -----------------------------------------------------------------------------------------
# There are 12792 records in test set
# Test set is composed by 6396 normal records and 6396 abnormal records

# %%
args = {}
nc = dataset['x_train'].shape[1]
nz = 100
manualseed = -1
print_freq = 100
args['w_adv'] = 1
args['w_con'] = 50
args['w_enc'] = 1
isTrain = True

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 200
seed = 42
pr_list = []

for i in range(n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_NSLKDD(PATH_TRAIN, PATH_TEST, seed*(i+1), show=False)
    
    # Convert Normal Label in 0 and Anomalous in 1
    dataset['y_test'].replace({1:0, 0:1}, inplace = True)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    ganomaly = GANomaly(nc, nz, device)
    
    _auc, pr_auc = ganomaly.train_and_test(train_loader, test_loader, args, n_epochs, batch_size)
    
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 1
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.028 | g_loss: 0.1940
# [INFO] Training phase... Elapsed time: 356 seconds
# PR AUC: 0.98
# AUC: 0.97
# Iteration: 2
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.029 | g_loss: 0.2608
# [INFO] Training phase... Elapsed time: 357 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 3
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.2782
# [INFO] Training phase... Elapsed time: 357 seconds
# PR AUC: 0.99
# AUC: 0.98
# Iteration: 4
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.025 | g_loss: 0.2070
# [INFO] Training phase... Elapsed time: 349 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 5
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.025 | g_loss: 0.3066
# [INFO] Training phase... Elapsed time: 347 seconds
# PR AUC: 0.99
# AUC: 0.99
# Iteration: 6
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.2298
# [INFO] Training phase... Elapsed time: 355 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 7
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.025 | g_loss: 0.2095
# [INFO] Training phase... Elapsed time: 359 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 8
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.2660
# [INFO] Training phase... Elapsed time: 349 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 9
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.025 | g_loss: 0.2106
# [INFO] Training phase... Elapsed time: 361 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 10
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.1911
# [INFO] Training phase... Elapsed time: 349 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 11
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.025 | g_loss: 0.2754
# [INFO] Training phase... Elapsed time: 358 seconds
# PR AUC: 0.98
# AUC: 0.97
# Iteration: 12
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.2698
# [INFO] Training phase... Elapsed time: 334 seconds
# PR AUC: 0.97
# AUC: 0.96
# Iteration: 13
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.025 | g_loss: 0.1959
# [INFO] Training phase... Elapsed time: 361 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 14
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.027 | g_loss: 0.1986
# [INFO] Training phase... Elapsed time: 348 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 15
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.026 | g_loss: 0.2298
# [INFO] Training phase... Elapsed time: 342 seconds
# PR AUC: 0.99
# AUC: 0.98
# Iteration: 16
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.3243
# [INFO] Training phase... Elapsed time: 343 seconds
# PR AUC: 0.98
# AUC: 0.97
# Iteration: 17
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.025 | g_loss: 0.2609
# [INFO] Training phase... Elapsed time: 355 seconds
# PR AUC: 0.98
# AUC: 0.97
# Iteration: 18
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.1836
# [INFO] Training phase... Elapsed time: 360 seconds
# PR AUC: 0.98
# AUC: 0.98
# Iteration: 19
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.2604
# [INFO] Training phase... Elapsed time: 358 seconds
# PR AUC: 0.98
# AUC: 0.97
# Iteration: 20
# [INFO] Starting training phase...
#
# Epoch [200/200] | d_loss: 0.024 | g_loss: 0.3009
# [INFO] Training phase... Elapsed time: 357 seconds
# PR AUC: 0.85
# AUC: 0.85

# %%
meanAUC_PRAUC(auc_list, pr_list, 'GANomaly_NSLKDD')
# Out:
# AUC:
# [0.974712064509518, 0.9789246650404158, 0.9837110538716153, 0.9807886397885485, 0.9868392671154306, 0.9795787661026416, 0.9790780549600848, 0.979153014352701, 0.9808732792462143, 0.979945508567151, 0.9711564983938914, 0.9628047289366674, 0.9767396470237614, 0.9795651993448062, 0.9842301962491411, 0.9724534682206398, 0.9735550645122557, 0.9788868247861294, 0.9710339575704171, 0.8450981323927831]
# **************
# PR AUC:
# [0.9803617208471841, 0.9824325125076682, 0.9865708076331005, 0.983161074382423, 0.9889894560922526, 0.9766239796410716, 0.9815718103964748, 0.9833511425206506, 0.9804347282893731, 0.9828126359447981, 0.9761873203267477, 0.9700873604426352, 0.9780396165309175, 0.9822663407736638, 0.987081801218317, 0.9764198146531318, 0.9800577330804331, 0.9831957292894533, 0.9778592361435103, 0.8538640541501993]
# **************
# AUC
# 0.97 +/- 0.01
# 95% confidence level, average auc would be between 0.96 and 0.98
# **************
# PR AUC
# 0.97 +/- 0.01
# 95% confidence level, average auc would be between 0.96 and 0.99

# %% [markdown]
# ---
