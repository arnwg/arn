# %% [markdown]
# ---

# %% [markdown]
# # CoverType

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '2'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')

from load_data import get_CoverType
from model_ganomaly import GANomaly

# %%
def meanAUC_PRAUC(auc_list, pr_list, name):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AUC_Frame.to_csv(f'./auc/{name}.csv', index=False)
    PR_AUC_Frame.to_csv(f'./auc_PR/{name}.csv', index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

WORK_SPACE = '../Dataset'
FILE = 'covtype.data'

DATASET = 'CoverType'

PATH = os.path.join(WORK_SPACE, DATASET, FILE)

# %%
dataset = get_CoverType(PATH, seed, show=True)
# Out:
# 530895 normal records, 50117 anormal records
# We use 25059 anomalous records
# -----------------------------------------------------------------------------------------
# There are 444764 records in training set
# Training set is composed by 444764 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 27797 records in validation set
# Validation set is composed by 21532 normal records and 6265 abnormal records
# -----------------------------------------------------------------------------------------
# There are 83393 records in test set
# Test set is composed by 64599 normal records and 18794 abnormal records

# %%
args = {}
nc = dataset['x_train'].shape[1]
nz = 100
manualseed = -1
print_freq = 100
args['w_adv'] = 1
args['w_con'] = 50
args['w_enc'] = 1
isTrain = True

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 50
seed = 42
pr_list = []

try:
    for i in range(n_runs):
        print(f'Iteration: {i+1}')
        dataset = get_CoverType(PATH, seed*(i+1), show=False)
        
        # Convert Normal Label in 0 and Anomalous in 1
        dataset['y_test'].replace({1:0, 0:1}, inplace = True)

        train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                                  torch.tensor(dataset['y_train'].to_numpy()).to(device))

        train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

        val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                                  torch.tensor(dataset['y_val'].to_numpy()).to(device))
        val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

        test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                                  torch.tensor(dataset['y_test'].to_numpy()).to(device))
        test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)

        ganomaly = GANomaly(nc, nz, device)
    
        _auc, pr_auc = ganomaly.train_and_test(train_loader, test_loader, args, n_epochs, batch_size)
    
        print(f'AUC: {_auc:.2f}')
        auc_list.append(_auc)
        pr_list.append(pr_auc)
except KeyboardInterrupt:
    print('--')
# Out:
# Iteration: 1
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.011 | g_loss: 0.7048
# [INFO] Training phase... Elapsed time: 762 seconds
# PR AUC: 0.18
# AUC: 0.36
# Iteration: 2
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.6798
# [INFO] Training phase... Elapsed time: 714 seconds
# PR AUC: 0.19
# AUC: 0.37
# Iteration: 3
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.011 | g_loss: 0.6435
# [INFO] Training phase... Elapsed time: 716 seconds
# PR AUC: 0.40
# AUC: 0.71
# Iteration: 4
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.011 | g_loss: 0.7809
# [INFO] Training phase... Elapsed time: 717 seconds
# PR AUC: 0.21
# AUC: 0.45
# Iteration: 5
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.011 | g_loss: 0.7435
# [INFO] Training phase... Elapsed time: 714 seconds
# PR AUC: 0.21
# AUC: 0.41
# Iteration: 6
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.7855
# [INFO] Training phase... Elapsed time: 708 seconds
# PR AUC: 0.37
# AUC: 0.59
# Iteration: 7
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.011 | g_loss: 0.6775
# [INFO] Training phase... Elapsed time: 709 seconds
# PR AUC: 0.37
# AUC: 0.68
# Iteration: 8
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.011 | g_loss: 0.7678
# [INFO] Training phase... Elapsed time: 707 seconds
# PR AUC: 0.28
# AUC: 0.61
# Iteration: 9
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.6746
# [INFO] Training phase... Elapsed time: 680 seconds
# PR AUC: 0.31
# AUC: 0.64
# Iteration: 10
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.012 | g_loss: 0.7757
# [INFO] Training phase... Elapsed time: 659 seconds
# PR AUC: 0.22
# AUC: 0.51
# Iteration: 11
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.7195
# [INFO] Training phase... Elapsed time: 655 seconds
# PR AUC: 0.27
# AUC: 0.59
# Iteration: 12
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.7640
# [INFO] Training phase... Elapsed time: 667 seconds
# PR AUC: 0.38
# AUC: 0.57
# Iteration: 13
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.7847
# [INFO] Training phase... Elapsed time: 663 seconds
# PR AUC: 0.32
# AUC: 0.64
# Iteration: 14
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.7910
# [INFO] Training phase... Elapsed time: 661 seconds
# PR AUC: 0.31
# AUC: 0.61
# Iteration: 15
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.013 | g_loss: 0.8607
# [INFO] Training phase... Elapsed time: 645 seconds
# PR AUC: 0.35
# AUC: 0.66
# Iteration: 16
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.009 | g_loss: 0.5901
# [INFO] Training phase... Elapsed time: 663 seconds
# PR AUC: 0.48
# AUC: 0.77
# Iteration: 17
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.7723
# [INFO] Training phase... Elapsed time: 670 seconds
# PR AUC: 0.34
# AUC: 0.65
# Iteration: 18
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.7301
# [INFO] Training phase... Elapsed time: 656 seconds
# PR AUC: 0.25
# AUC: 0.56
# Iteration: 19
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.8556
# [INFO] Training phase... Elapsed time: 667 seconds
# PR AUC: 0.18
# AUC: 0.32
# Iteration: 20
# [INFO] Starting training phase...
#
# Epoch [ 50/50] | d_loss: 0.010 | g_loss: 0.6563
# [INFO] Training phase... Elapsed time: 665 seconds
# PR AUC: 0.37
# AUC: 0.56

# %%
meanAUC_PRAUC(auc_list, pr_list, 'GANomaly_CoverType')
# Out:
# AUC:
# [0.3582092521826885, 0.3679825953649799, 0.714586665678654, 0.44647339693504545, 0.41463726335221884, 0.5938163554805095, 0.6830375472308885, 0.6090987769155077, 0.6362120893516896, 0.5117264776448818, 0.5913800134948325, 0.5737947020322588, 0.6396196965837012, 0.6075005789228896, 0.6611122629083825, 0.7668178575821869, 0.6535314597721351, 0.5601274133126982, 0.3214695662364972, 0.5638324086093344]
# **************
# PR AUC:
# [0.18032433432737596, 0.1903481296107306, 0.40463966970509346, 0.21397970172141234, 0.20994545223755975, 0.3682148935223243, 0.3724331423986139, 0.27775244304888713, 0.31391338719968487, 0.2238142247360887, 0.2680665418484658, 0.3782203816231393, 0.3212726221143309, 0.30889703453619033, 0.3488565833956373, 0.48230483254798795, 0.3363907979294757, 0.2489747099716263, 0.17705203177675471, 0.3659644886771972]
# **************
# AUC
# 0.56 +/- 0.05
# 95% confidence level, average auc would be between 0.51 and 0.62
# **************
# PR AUC
# 0.30 +/- 0.04
# 95% confidence level, average auc would be between 0.26 and 0.34

# %% [markdown]
# ---
