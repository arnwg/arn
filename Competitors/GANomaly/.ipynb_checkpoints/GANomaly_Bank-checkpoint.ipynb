# %% [markdown]
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch import nn

from time import time
from tqdm import tqdm

from sklearn.metrics import roc_auc_score, average_precision_score,auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, auc, precision_recall_curve
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from sklearn.utils import shuffle

import pandas as pd
import os
import sys

seed = 1234
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

os.environ['CUDA_VISIBLE_DEVICES'] = '0'

device = torch.device('cuda' if (torch.cuda.is_available()) else 'cpu')
print('[INFO] -> Using Device: ', device)

from load_data import get_Bank
from model_ganomaly import GANomaly
# Out:
# [INFO] -> Using Device:  cuda

# %%
def meanAUC_PRAUC(auc_list, pr_list, name, SPACE_AUC, SPACE_AUPRC):
    print('AUC:')
    print(auc_list)
    print('**************')
    print('PR AUC:')
    print(pr_list)
    print('**************')
    
    
    AUC_Frame = pd.DataFrame(auc_list, columns = [name])
    PR_AUC_Frame = pd.DataFrame(pr_list, columns = [name])
    
    AU_NAME = f'{name}.csv'
    
    AUC_Frame.to_csv(os.path.join(SPACE_AUC, AU_NAME), index=False)
    PR_AUC_Frame.to_csv(os.path.join(SPACE_AUPRC, AU_NAME), index=False)
    
    AUC_Frame = list(AUC_Frame[name])

    N = len(AUC_Frame)
    mean_auc = np.mean(AUC_Frame)
    std_auc = np.std(AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')
    print('**************')
    
    PR_AUC_Frame = list(PR_AUC_Frame[name])

    N = len(PR_AUC_Frame)
    mean_auc = np.mean(PR_AUC_Frame)
    std_auc = np.std(PR_AUC_Frame)
    std_error = std_auc / (np.sqrt(N))

    ci = 1.96 * std_error
    lower_bound = mean_auc - ci
    upper_bound = mean_auc + ci
    
    print('PR AUC')
    print(f'{mean_auc:.2f} +/- {ci:.2f}')
    print(f'95% confidence level, average auc would be between {lower_bound:.2f} and {upper_bound:.2f}')

# %%
batch_size = 1024

BASE_PATH = '../Dataset'

DATASET_FILE = 'bank-additional-ful-nominal.arff'

SPACE_MODELS = './models'
SPACE_AUC = './auc'
SPACE_AUPRC = './auprc'

for n in (SPACE_MODELS, SPACE_AUC, SPACE_AUPRC):
    if not os.path.exists(n):
        os.mkdir(n)
        
DATASET = 'BANK'

PATH = os.path.join(BASE_PATH, 'Dataset', DATASET_FILE)

# %%
dataset = get_Bank(PATH, seed, show=True)
# Out:
# 36548 normal records, 4640 anormal records
# We use 2321 anomalous records
# -----------------------------------------------------------------------------------------
# There are 26383 records in training set
# Training set is composed by 26383 normal records and 0 abnormal records
# -----------------------------------------------------------------------------------------
# There are 3131 records in validation set
# Validation set is composed by 2551 normal records and 580 abnormal records
# -----------------------------------------------------------------------------------------
# There are 9354 records in test set
# Test set is composed by 7614 normal records and 1740 abnormal records

# %%
args = {}
nc = dataset['x_train'].shape[1]
nz = 100
manualseed = -1
print_freq = 100
args['w_adv'] = 1
args['w_con'] = 50
args['w_enc'] = 1
isTrain = True

# %% [markdown]
# #### Mean AUC and standard deviation after seven runs

# %%
n_runs = 20
auc_list = []
n_epochs = 400
seed = 42
pr_list = []

for i in range(n_runs):
    print(f'Iteration: {i+1}')
    dataset = get_Bank(PATH, seed*(i+1), show=False)
    
    # Convert Normal Label in 0 and Anomalous in 1
    dataset['y_test'].replace({1:0, 0:1}, inplace = True)
    
    train_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_train']).to(device), 
                                              torch.tensor(dataset['y_train'].to_numpy()).to(device))
    
    train_loader = DataLoader(dataset=train_dataset, batch_size = batch_size, shuffle=True, drop_last = True)

    val_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_val']).to(device), 
                                              torch.tensor(dataset['y_val'].to_numpy()).to(device))
    val_loader = DataLoader(dataset=val_dataset, batch_size = batch_size, shuffle=False)

    test_dataset = torch.utils.data.TensorDataset(torch.tensor(dataset['x_test']).to(device), 
                                              torch.tensor(dataset['y_test'].to_numpy()).to(device))
    test_loader = DataLoader(dataset=test_dataset, batch_size = batch_size, shuffle=False)
    
    ganomaly = GANomaly(nc, nz, device)
    
    _auc, pr_auc = ganomaly.train_and_test(train_loader, test_loader, args, n_epochs, batch_size)
    
    print(f'AUC: {_auc:.2f}')
    auc_list.append(_auc)
    pr_list.append(pr_auc)
# Out:
# Iteration: 1
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.038 | g_loss: 4.540
# [INFO] Training phase... Elapsed time: 282 seconds
# PR AUC: 0.20
# AUC: 0.51
# Iteration: 2
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.041 | g_loss: 4.486
# [INFO] Training phase... Elapsed time: 281 seconds
# PR AUC: 0.22
# AUC: 0.52
# Iteration: 3
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.041 | g_loss: 3.999
# [INFO] Training phase... Elapsed time: 282 seconds
# PR AUC: 0.23
# AUC: 0.51
# Iteration: 4
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.041 | g_loss: 4.496
# [INFO] Training phase... Elapsed time: 284 seconds
# PR AUC: 0.23
# AUC: 0.51
# Iteration: 5
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.038 | g_loss: 4.185
# [INFO] Training phase... Elapsed time: 285 seconds
# PR AUC: 0.17
# AUC: 0.48
# Iteration: 6
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.040 | g_loss: 4.275
# [INFO] Training phase... Elapsed time: 282 seconds
# PR AUC: 0.25
# AUC: 0.57
# Iteration: 7
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.040 | g_loss: 4.152
# [INFO] Training phase... Elapsed time: 284 seconds
# PR AUC: 0.18
# AUC: 0.51
# Iteration: 8
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.042 | g_loss: 4.389
# [INFO] Training phase... Elapsed time: 281 seconds
# PR AUC: 0.24
# AUC: 0.53
# Iteration: 9
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.044 | g_loss: 4.508
# [INFO] Training phase... Elapsed time: 280 seconds
# PR AUC: 0.19
# AUC: 0.51
# Iteration: 10
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.044 | g_loss: 4.503
# [INFO] Training phase... Elapsed time: 283 seconds
# PR AUC: 0.20
# AUC: 0.51
# Iteration: 11
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.040 | g_loss: 4.494
# [INFO] Training phase... Elapsed time: 278 seconds
# PR AUC: 0.19
# AUC: 0.45
# Iteration: 12
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.042 | g_loss: 4.105
# [INFO] Training phase... Elapsed time: 279 seconds
# PR AUC: 0.19
# AUC: 0.53
# Iteration: 13
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.042 | g_loss: 4.061
# [INFO] Training phase... Elapsed time: 278 seconds
# PR AUC: 0.19
# AUC: 0.49
# Iteration: 14
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.049 | g_loss: 4.253
# [INFO] Training phase... Elapsed time: 278 seconds
# PR AUC: 0.25
# AUC: 0.63
# Iteration: 15
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.039 | g_loss: 4.221
# [INFO] Training phase... Elapsed time: 278 seconds
# PR AUC: 0.24
# AUC: 0.54
# Iteration: 16
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.051 | g_loss: 4.291
# [INFO] Training phase... Elapsed time: 279 seconds
# PR AUC: 0.24
# AUC: 0.54
# Iteration: 17
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.040 | g_loss: 4.888
# [INFO] Training phase... Elapsed time: 278 seconds
# PR AUC: 0.23
# AUC: 0.57
# Iteration: 18
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.038 | g_loss: 4.376
# [INFO] Training phase... Elapsed time: 277 seconds
# PR AUC: 0.24
# AUC: 0.53
# Iteration: 19
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.040 | g_loss: 4.295
# [INFO] Training phase... Elapsed time: 277 seconds
# PR AUC: 0.34
# AUC: 0.64
# Iteration: 20
# [INFO] Starting training phase...
#
# Epoch [400/400] | d_loss: 0.041 | g_loss: 4.184
# [INFO] Training phase... Elapsed time: 278 seconds
# PR AUC: 0.16
# AUC: 0.44

# %%
meanAUC_PRAUC(auc_list, pr_list, f'GANomaly_{DATASET}', SPACE_AUC, SPACE_AUPRC)
# Out:
# AUC:
# [0.5129808142290819, 0.52011879206181, 0.511400467680528, 0.5102273036058803, 0.47590554604494445, 0.5743036119187582, 0.5068286942685737, 0.5300605886313475, 0.5104311024156952, 0.5117325842594858, 0.45117807034229146, 0.5340026237209737, 0.485927843144359, 0.631429890190182, 0.5383949786992503, 0.53690936085674, 0.5707429825276487, 0.5295406374826772, 0.6412059303944035, 0.43733571551497696]
# **************
# PR AUC:
# [0.20330514973582875, 0.22194711417719998, 0.22527213799043536, 0.22930993708017844, 0.17392569337801667, 0.2526333563667755, 0.1834779979359501, 0.24408958256802402, 0.1887291408476451, 0.19988211296240543, 0.1901001371266042, 0.19373529951438168, 0.18527722996037674, 0.2539941063351125, 0.24407117036994627, 0.23564923946052538, 0.22504964780655787, 0.23710278130781487, 0.33856287456477774, 0.16450989665364898]
# **************
# AUC
# 0.53 +/- 0.02
# 95% confidence level, average auc would be between 0.50 and 0.55
# **************
# PR AUC
# 0.22 +/- 0.02
# 95% confidence level, average auc would be between 0.20 and 0.24

# %% [markdown]
# ---
